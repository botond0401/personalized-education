# %% [markdown]
# # 1) Imports

# %%
import json
import sys
import os
import pandas as pd
import random
import torch
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

from torch.utils.data import Dataset
from torch.nn.utils.rnn import pad_sequence

from collections import defaultdict
from typing import Union, List

from typing import Dict, Any, Optional, Tuple
from tqdm import tqdm
import torch.nn as nn
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import torch.nn.functional as F
from sklearn.metrics import roc_auc_score
import numpy as np
from sklearn.model_selection import KFold

# %%
def set_seed(seed):
    # Python random seed
    random.seed(seed)

    # NumPy random seed
    np.random.seed(seed)

    # PyTorch random seed (CPU)
    torch.manual_seed(seed)

    # PyTorch random seed (GPU, if applicable)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)  # For all GPUs

    # For deterministic behavior
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Set a seed
seed = 42
set_seed(seed)

# %% [markdown]
# # 2) Defining Classes and Functions

# %%
class SequenceDataset(Dataset):
    def __init__(self, user_dict):

      # sorting in order to make apdding more efficient
      self.user_ids = sorted(user_dict.keys(), key=lambda x: len(user_dict[x]))
      self.sequences = [user_dict[user_id] for user_id in self.user_ids]

    def __getitem__(self, indices):
      sequence = self.sequences[indices]
      skill_one_hot_vectors = torch.tensor(np.array([item[0] for item in sequence[:-1]]), dtype=torch.float32)
      if len(sequence[0]) == 2:
          # Convert the list comprehension to a numpy array first, then to a tensor
          additional_features = torch.tensor(np.array([item[1] for item in sequence[:-1]]), dtype=torch.float32)
          additional_features = additional_features.unsqueeze(-1)  # Add the extra dimension
      else:
          # Convert the list comprehension to a numpy array first, then to a tensor
          additional_features = torch.tensor(np.array([list(item[1]) + [item[2]] for item in sequence[:-1]]), dtype=torch.float32)

      # Optimize labels creation
      labels = torch.tensor(np.array([list(item[0]) + [item[-1]] for item in sequence[1:]]), dtype=torch.float32)

      return skill_one_hot_vectors, additional_features, labels

    def __len__(self):
        return len(self.sequences)


# Define collate function
def collate_batch(batch):
    # Unpacking batches into sequences and labels
    skill_one_hot_vectors, additional_features, labels = zip(*batch)  # This will now work as expected

    # Convert sequences to padded tensors
    skill_one_hot_vectors_padded = pad_sequence(skill_one_hot_vectors, batch_first=True, padding_value=0)  # Pad inputs to max length
    additional_features_padded = pad_sequence(additional_features, batch_first=True, padding_value=0)  # Pad targets to max length
    labels_padded = pad_sequence(labels, batch_first=True, padding_value=0)  # Pad targets to max length
    lengths = torch.tensor([len(label) for label in labels])

    return skill_one_hot_vectors_padded, additional_features_padded, labels_padded, lengths

# %%
class KTDataset():
    def __init__(self,
                 df_answers,
                 df_skill_names,
                 renumber_skill_ids=True,
                 prepare_BKT=False,
                 prepare_DKT=False,
                 additional_columns=None):

        self.df_answers = df_answers
        self.df_skill_names = df_skill_names
        self.num_skills = len(df_skill_names)
        self.BKT_datadict = None
        self.DKT_datadict = None
        self.additional_columns = additional_columns
        self.num_other = 1 + (len(additional_columns) if additional_columns is not None else 0)

        if renumber_skill_ids:
            # Map original skill IDs to a continuous range starting from 1
            unique_skill_ids = sorted(df_skill_names['skill_id'].astype(int).unique())
            self.skill_id_mapping = {original_id: new_id for new_id, original_id in enumerate(unique_skill_ids, start=1)}
            # Apply the mapping to create the new column
            df_skill_names['skill_ids_renumbered'] = df_skill_names['skill_id'].map(self.skill_id_mapping)
        else:
            self.skill_id_mapping = None

        if prepare_BKT:
            self.create_BKT_datadict()

        if prepare_DKT:
            self.create_DKT_datadict()


    def return_ordered_ids(self, ids: Union[int, str, List[int], List[str]]) -> Union[int, List[int]]:
        """
        Returns renumbered skill IDs based on the mapping.

        Args:
            ids (Union[int, str, List[int], List[str]]): Original skill ID(s) to be renumbered.

        Returns:
            Union[int, List[int]]: Renumbered skill ID(s).
        """

        if isinstance(ids, (int, str)):
            return self.skill_id_mapping[int(ids)]
        elif isinstance(ids, list):
            return [self.skill_id_mapping[int(id)] for id in ids]
        else:
            raise TypeError("IDs must be an int, str, or a list of int/str.")


    def return_original_ids(self, ids: Union[int, str, List[int], List[str]]) -> Union[int, List[int]]:
        """
        Returns original skill IDs based on the renumbered skill IDs.

        Args:
            ids (Union[int, str, List[int], List[str]]): Renumbered skill ID(s) to be mapped back to the original IDs.

        Returns:
            Union[int, str, List[int], List[str]]: Original skill ID(s).
        """

        if isinstance(ids, (int, str)):
            return self.original_id_mapping.get(int(ids), None)  # Convert to integer for lookup
        elif isinstance(ids, list):
            return [self.original_id_mapping.get(int(id), None) for id in ids]  # Convert each to integer for lookup
        else:
            raise TypeError("IDs must be an int, str, or a list of int/str.")


    def create_BKT_datadict(self):
        """
        Converts Assistments data into a Bayesian Knowledge Tracing (BKT) dictionary.

        Groups data by skill ID and user ID, creating a structure where each skill maps
        to lists of user answer sequences.
        """

        # Create a defaultdict to collect answer sequences per skill
        skill_dict = defaultdict(list)

        for _, row in self.df_skill_names.iterrows():
            skill_id = row['skill_id']
            skill_name = row['skill_name']

            df_answers_filtered = self.df_answers[self.df_answers[str(skill_id)] == 1]
            # Group by user_id and collect sequences of correct answers
            answer_list = df_answers_filtered.groupby('user_id')['correct'].apply(list)

            # Collect all answer sequences for the current skill
            skill_dict[f"{skill_id} ({skill_name})"] = answer_list.tolist()

        # Convert defaultdict to a regular dictionary and return
        self.BKT_datadict = dict(skill_dict)


    def create_DKT_datadict(self):
        """
        Create a DKT dataset with one-hot vectors and additional columns if specified.
        """
        add_col = self.additional_columns

        # Dictionary to hold the data for each user
        dict_skills = defaultdict(list)

        # Iterate over each user group
        for user_id, user_group in self.df_answers.groupby('user_id'):
            # Create a list of tuples for each user's answers
            answer_list = []
            for _, row in user_group.iterrows():
                one_hot_vector = row.iloc[-self.num_skills:].values  # Extract the one-hot vector as an array

                # Collect additional column values as a list
                additional_info = row[add_col].values if add_col else []

                is_correct = row['correct']  # Extract if the answer was correct

                # Append the tuple (one-hot vector, additional info, correct flag)
                if add_col:
                    answer_list.append((one_hot_vector, additional_info, is_correct))
                else:
                    answer_list.append((one_hot_vector, is_correct))

            # Store the answer list in the dictionary under the user ID
            dict_skills[user_id] = answer_list

        self.DKT_datadict = dict(dict_skills)

# %%
class CustomEmbedding(nn.Module):
    def __init__(self, num_skills, embed_dim):
        super(CustomEmbedding, self).__init__()
        # Linear layer for embedding
        self.linear = nn.Linear(num_skills, embed_dim, bias=False)
        # Tanh activation
        self.tanh = nn.Tanh()

    def forward(self, x):
        # Perform the linear transformation
        embedded = self.linear(x)

        # Calculate the number of 1s (sum of the input binary vector)
        num_ones = torch.sum(x, dim=-1, keepdim=True)

        # Broadcast num_ones to the shape of embedded: (batch_size, seq_len, embed_dim)
        num_ones = num_ones.expand(-1, -1, embedded.size(-1))

        # Avoid division by zero
        num_ones = torch.max(num_ones, torch.ones_like(num_ones))

        # Divide the embedded vector by the number of 1s
        embedded /= num_ones

        # Apply the Tanh activation
        return embedded

# %%
class DKT(nn.Module):
    def __init__(self, num_skills, num_other, embed_dim, hid_size, num_hid_layers, drop_prob):
        super(DKT, self).__init__()

        self.num_skills = num_skills
        self.num_other = num_other
        self.embed_dim = embed_dim
        self.hid_size = hid_size
        self.num_hid_layers = num_hid_layers
        self.drop_prob = drop_prob

        # Custom embedding layer
        self.embedding = CustomEmbedding(num_skills, embed_dim)

        # RNN layer
        self.rnn = nn.LSTM(embed_dim + num_other, hid_size, num_hid_layers, batch_first=True)

        # Dropout layer for regularization
        self.dropout = nn.Dropout(p=drop_prob)

        # Output layer mapping hidden states to probabilities
        self.out = nn.Linear(hid_size, num_skills)

        # Sigmoid for probability output
        self.sigmoid = nn.Sigmoid()

    def forward(self, skills, other, lengths):
        """
        Forward pass for the DKT model.

        Args:
            inputs (Tensor): Input sequence of shape (batch_size, seq_len, 2), where each entry is (problem_id, correct).
            lengths (Tensor): Lengths of sequences (batch_size).

        Returns:
            Tensor: Output probabilities of shape (batch_size, seq_len, num_items).
        """
        # Embed the input sequence
        embedded = self.embedding(skills)

        concatenated = torch.cat((embedded, other), dim=-1)  # (batch_size, seq_length, embed_dim+other_dim)

        # Pack the padded sequence for the RNN
        packed_embedded = pack_padded_sequence(concatenated, lengths, batch_first=True, enforce_sorted=False)

        # RNN processing
        packed_output, _ = self.rnn(packed_embedded)

        # Unpack the sequence
        output, _ = pad_packed_sequence(packed_output, batch_first=True)

        # Apply dropout
        output = self.dropout(output)

        # Output layer for probabilities
        logits = self.out(output)

        # Sigmoid to convert logits to probabilities
        probabilities = self.sigmoid(logits)

        return probabilities

    def get_embedding(self, skill_id):
        one_hot = torch.zeros(1, 1, self.num_skills)
        one_hot[0, 0, skill_id] = 1
        embedding = self.embedding(one_hot)
        return embedding.squeeze(0).squeeze(0).detach().numpy()

# %%
def calculate_DKT_loss(predictions_all, answers_with_labels, lengths):
    """
    Calculate the binary cross-entropy loss for a sequence of predictions and labels,
    while ignoring padded positions based on the given lengths.

    Args:
        predictions_all (Tensor): The model's predicted values with shape (batch_size, seq_len, num_skills).
        answers_with_labels (Tensor): Ground truth tensor with shape (batch_size, seq_len, num_skills + 1),
                                      where the last dimension contains problem IDs and correctness labels.
                                      The last element of each entry indicates whether the response was correct (1) or not (0).
        lengths (Tensor): A tensor of shape (batch_size,) indicating the lengths of each sequence in the batch.

    Returns:
        loss (Tensor): The total binary cross-entropy loss for the batch, ignoring padded positions.
    """
    # Extract the result (predictions) and labels from the inputs
    result, labels = _transform_to_correct_predictions(predictions_all, answers_with_labels)

    # Create a mask based on the sequence lengths, where 1 represents a valid position and 0 represents padding
    batch_size, seq_len = result.size()  # Assuming result is (batch_size, seq_len)

    lengths = lengths.to(device)
    mask = torch.arange(seq_len, device=result.device).expand(batch_size, seq_len) < lengths.unsqueeze(1)
    mask = mask.float()  # Convert to float for later multiplication

    # Apply the mask to the result and labels to ignore padded positions
    masked_result = result * mask
    masked_labels = labels * mask

    # Compute the binary cross-entropy loss for each sequence element
    loss = F.binary_cross_entropy(masked_result, masked_labels, reduction='none')

    # Average the loss over the non-padded positions
    masked_loss = loss.sum() / mask.sum()  # Normalize by the number of valid (non-padded) positions

    return masked_loss


def calculate_auc(predictions_all, answers_with_labels, lengths):
    """
    Calculate the AUC (Area Under the Curve) for a sequence of predictions and labels, considering valid (non-padded) data.

    Args:
        predictions_all (Tensor): The model's predicted values with shape (batch_size, seq_len, num_skills).
        answers_with_labels (Tensor): Ground truth tensor with shape (batch_size, seq_len, num_skills + 1),
                                     where the last element indicates correctness.
        lengths (Tensor): Lengths of sequences for each batch, to ignore padded values.

    Returns:
        auc (float): AUC score for the batch.
    """
    # Extract problem_ids and labels from the inputs
    predictions, labels = _transform_to_correct_predictions(predictions_all, answers_with_labels)

    # Move tensors to CPU and convert to NumPy arrays for AUC calculation
    predictions = predictions.cpu().detach().numpy()  # Move to CPU first
    labels = labels.cpu().detach().numpy()  # Same for labels
    lengths = lengths.cpu().detach().numpy()

    # Create mask to ignore padded values based on sequence lengths
    mask = np.arange(predictions.shape[1])[None, :] < lengths[:, None]  # Shape: (batch_size, seq_len)

    # Apply the mask to filter valid predictions and labels without using np.nan
    valid_predictions = predictions[mask]
    valid_labels = labels[mask]

    # Calculate AUC if valid data is present
    if valid_predictions.size > 0 and valid_labels.size > 0:
        auc = roc_auc_score(valid_labels, valid_predictions)
    else:
        auc = float('nan')  # Return NaN if no valid data for AUC calculation

    return auc


# Assuming test_loader is your DataLoader for the test set
def evaluate_auc(model, test_loader, device):
    model.eval()  # Set the model to evaluation mode
    auc_scores = []

    with torch.no_grad():  # Disable gradient computation for evaluation
        for skill_sequences, other_sequences, answers, lengths in test_loader:
            # Move inputs and answers to the correct device (GPU/CPU)
            skill_sequences = skill_sequences.to(device)
            other_sequences = other_sequences.to(device)
            answers = answers.to(device)
            lengths = lengths.to('cpu')

            # Forward pass through the model
            predictions = model(skill_sequences, other_sequences, lengths)  # Shape (batch_size, seq_len, num_items)

            # Calculate AUC for the current batch
            auc = calculate_auc(predictions, answers, lengths)
            auc_scores.append(auc)

    # Calculate the average AUC over all batches
    average_auc = sum(auc_scores) / len(auc_scores)
    return average_auc


def _transform_to_correct_predictions(predictions_all, answers_with_labels):
    # Extract problem IDs (skills) and correctness labels from the inputs
    problem_ids = answers_with_labels[..., :-1]  # Shape: (batch_size, seq_len, num_skills)
    labels = answers_with_labels[..., -1]   # Shape: (batch_size, seq_len)

    # Element-wise multiplication of predictions and problem IDs to select relevant predictions
    product = predictions_all * problem_ids  # Shape: (batch_size, seq_len, num_skills)

    # Sum over the skill dimension to aggregate predictions for each sequence step
    result_sum = product.sum(dim=2)  # Shape: (batch_size, seq_len)

    # Count the number of relevant skills (ones) for each step to use as a normalization factor
    num_ones = problem_ids.sum(dim=2)  # Shape: (batch_size, seq_len)

    # Avoid division by zero by aclipping at 1
    normalization_factor = torch.clamp(num_ones, min=1)

    # Normalize the summed result by the number of ones (relevant skills)
    result = result_sum / normalization_factor  # Shape: (batch_size, seq_len)

    return result, labels

# %%
def process(model, loader, device, optim=None):
    """
    Process the data in the given loader for either training or evaluation.

    Args:
        model: The model to be used for predictions.
        loader: DataLoader providing batches of input data and labels.
        device: The device (CPU or GPU) to run the computation on.
        optim: Optimizer for training (if provided). If None, the function performs evaluation.

    Returns:
        total_loss (float): The sum of all batch losses.
        average_auc (float): The average AUC score across all batches.
    """
    # Set model to training or evaluation mode
    if optim is not None:
        model.train()
        desc = 'Training'
    else:
        model.eval()
        desc = 'Evaluation'

    total_loss = 0
    total_auc = 0
    total_samples = 0


    model = model.to(device)

    with torch.no_grad() if optim is None else torch.enable_grad():

      # Iterate through the DataLoader with tqdm for progress tracking
      for skill_sequences, other_sequences, labels, lengths in tqdm(loader,
                                                                    file=sys.stdout,
                                                                    unit=' batches',
                                                                    desc=desc):
          # Move sequences and labels to the appropriate device
          skill_sequences = skill_sequences.to(device)
          other_sequences = other_sequences.to(device)
          labels = labels.to(device)

          lengths = lengths.to('cpu')

          # Forward pass
          outputs = model(skill_sequences, other_sequences, lengths)

          loss = calculate_DKT_loss(outputs, labels, lengths)
          auc = calculate_auc(outputs, labels, lengths)

          if optim is not None:  # Only during training
              optim.zero_grad()  # Reset gradients
              loss.backward()  # Backpropagation
              max_grad_norm = 5e-5 # Set a maximum gradient norm for clipping
              nn.utils.clip_grad_norm_(model.parameters(), max_grad_norm)
              optim.step()  # Update parameters
              torch.cuda.empty_cache()

          batch_size = skill_sequences.size(0)  # Get the number of samples in the current batch

          # Weight the loss by the batch size
          total_loss += loss.item() * batch_size  # Accumulate weighted loss
          total_auc += auc * batch_size  # Accumulate weighted AUC
          total_samples += batch_size

    return total_loss / total_samples, total_auc / total_samples


def train_dkt(
    model_params: Dict[str, Any],
    lr: float,
    num_epochs: int,
    device: torch.device,
    train_loader: DataLoader,
    val_loader: Optional[DataLoader] = None,
    patience = 3
) -> Tuple[torch.nn.Module, float]:
    """
    Trains a Deep Knowledge Tracing (DKT) model using the provided parameters.

    Args:
        model_params (dict): A dictionary of model parameters to initialize the DKT model.
        lr (float): Learning rate for the optimizer.
        num_epochs (int): Number of epochs to train the model.
        device (torch.device): The device (e.g., 'cuda' or 'cpu') to run the training on.
        train_loader (DataLoader): DataLoader for the training dataset.
        val_loader (Optional[DataLoader]): DataLoader for the validation dataset. If None,
                                           training data is used for evaluation.

    Returns:
        Tuple[torch.nn.Module, float]: The trained DKT model and the best validation AUC achieved.

    Notes:
        - If `val_loader` is not provided, the training data is used for evaluation, which may
          lead to overestimation of the performance.
    """
    # Initialize the model and move it to the specified device
    model = DKT(**model_params)

    # Initialize the optimizer with the model's parameters and specified learning rate
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    list_train_loss = []
    list_train_auc = []
    list_val_loss = []
    list_val_auc = []

    # Initialize early stopping variables
    best_val_auc = 0.0
    epochs_without_improvement = 0

    # Training loop for the specified number of epochs
    for epoch in range(1, num_epochs + 1):

        # Training phase: Update the model using the training data
        # Check initial weights and biases of each layer
        process(model, train_loader, device, optimizer)

        # Validation phase: Evaluate the model on the validation dataset (if provided)
        if val_loader is not None:
            train_loss, train_auc = process(model, train_loader, device)
            val_loss, val_auc = process(model, val_loader, device)
            list_val_loss.append(val_loss)
            list_val_auc.append(val_auc)
        else:
            train_loss, train_auc = process(model, train_loader, device)
        list_train_loss.append(train_loss)
        list_train_auc.append(train_auc)

        print(f'For the {epoch}. epoch train AUC is {train_auc}, train loss is {train_loss}.')

        # Check for early stopping condition
        if patience:
          if val_auc > best_val_auc:
              best_val_auc = val_auc
              epochs_without_improvement = 0  # Reset the counter
          else:
              epochs_without_improvement += 1
          if epochs_without_improvement >= patience:
              print(f"Early stopping triggered after {epoch} epochs. No improvement in validation AUC for {patience} epochs.")
              break

    # Return the trained model and the best validation AUC achieved
    return model, list_train_loss, list_train_auc, list_val_loss, list_val_auc

# %%
def k_fold_cv_dkt(
    num_folds,
    model_params: Dict[str, Any],
    lr: float,
    num_epochs: int,
    device: torch.device,
    train_dict: Dict[int, Any],
    batch_size: int = 100,
    num_workers: int = 0
) -> float:
    """
    Perform k-fold cross-validation for the Deep Knowledge Tracing (DKT) model.

    Args:
        num_folds (int): Number of folds for cross-validation.
        model_params (Dict[str, Any]): Parameters for initializing the DKT model.
        lr (float): Learning rate for the optimizer.
        num_epochs (int): Number of epochs for training in each fold.
        device (torch.device): The device (e.g., 'cuda' or 'cpu') to run the training on.
        train_dict (Dict[int, Any]): Dictionary mapping keys to data for training.
        batch_size (int, optional): Batch size for training and validation. Defaults to 100.
        num_workers (int, optional): Number of subprocesses to use for data loading. Defaults to 2.

    Returns:
        float: The average validation AUC across all folds.

    Notes:
        - Assumes that the `train_dict` keys can be split into train and validation sets.
        - Requires an `AnswerSet` dataset and the `train_dkt` training function.
    """
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

    train_keys = list(train_dict.keys())

    val_auc_list = []

    for fold, (fold_train_idx, fold_val_idx) in enumerate(kf.split(train_keys)):
        print(f"\nFold {fold+1}/{num_folds}")
        fold_train_keys = [train_keys[i] for i in fold_train_idx]
        fold_val_keys = [train_keys[i] for i in fold_val_idx]

        fold_train_dict = {key: train_dict[key] for key in fold_train_keys}
        fold_train_dict = dict(sorted(fold_train_dict.items(), key=lambda item: len(item[1])))

        fold_val_dict = {key: train_dict[key] for key in fold_val_keys}
        fold_val_dict = dict(sorted(fold_val_dict.items(), key=lambda item: len(item[1])))

        fold_train_dataset = SequenceDataset(fold_train_dict)
        fold_train_loader = DataLoader(fold_train_dataset, batch_size=batch_size, collate_fn=collate_batch, pin_memory=True, num_workers=num_workers)

        fold_val_dataset = SequenceDataset(fold_val_dict)
        fold_val_loader = DataLoader(fold_val_dataset, batch_size=batch_size, collate_fn=collate_batch, pin_memory=True, num_workers=num_workers)

        *_, list_val_auc = train_dkt(
            model_params, lr, num_epochs, device,
            fold_train_loader, fold_val_loader
            )

        val_auc = list_val_auc[-1]

        val_auc_list.append(val_auc)
        print(f'\nFor the {fold+1}. fold AUC is {val_auc}.')

    val_auc_avg = sum(val_auc_list) / num_folds

    return val_auc_avg

# %%
def split(keys, val_ratio=0.2):
    """Splits keys into training and validation sets based on a specified validation ratio"""
    random.shuffle(keys)
    split_idx = int(len(keys) * (1 - val_ratio))
    train_idx = keys[:split_idx]
    val_idx = keys[split_idx:]
    return train_idx, val_idx

# %% [markdown]
# # 3) Model Training and Evaluation

# %% [markdown]
# ## 3.1) Data imports and transforms

# %%
df_answers = pd.read_csv('df_answers.csv')
df_skill_names = pd.read_csv('df_skill_names.csv')

skills_to_keep = [
    'Box and Whisker', 'Circle Graph', 'Histogram as Table or Graph', 'Number Line', 'Scatter Plot',
        'Stem and Leaf Plot', 'Table', 'Venn Diagram', 'Mean', 'Median', 'Mode', 'Range',
    'Probability of Two Distinct Events', 'Probability of a Single Event', 'D.4.8-understanding-concept-of-probabilities'
]
df_skill_names_filtered = df_skill_names[df_skill_names['skill_name'].isin(skills_to_keep)]

columns_to_keep = list(df_answers.columns[:8]) + list(df_skill_names_filtered['skill_id'].astype(str).values)

df_answers_filtered = df_answers[columns_to_keep]

df_answers_filtered = df_answers_filtered[df_answers_filtered[df_answers_filtered.columns[8:]].sum(axis=1) > 0]

# Get the value counts of 'user_id'
user_counts = df_answers_filtered['user_id'].value_counts()

# Identify the user_ids that appear more than once
valid_user_ids = user_counts[user_counts > 1].index

# Filter the DataFrame to keep only rows with user_ids in valid_user_ids
df_answers_filtered = df_answers_filtered[df_answers_filtered['user_id'].isin(valid_user_ids)]

# Display the filtered DataFrame
print(len(df_answers))
print(len(df_answers_filtered))
# Out:
# 301088
# 48812

# %%
#additional_columns = []
#additional_columns = ['ease']
additional_columns = ['ease', 'bottom_hint', 'hints_used', 'ms_first_response']

kt_dataset = KTDataset(df_answers_filtered, df_skill_names_filtered, prepare_DKT=True, additional_columns=additional_columns)

user_dict = kt_dataset.DKT_datadict
NUM_SKILLS = kt_dataset.num_skills
NUM_OTHER = kt_dataset.num_other
# Out:
# <ipython-input-4-cc8b76e1d5b7>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_skill_names['skill_ids_renumbered'] = df_skill_names['skill_id'].map(self.skill_id_mapping)

# %% [markdown]
# ## 3.2) Seting constants

# %%
train_ratio = 0.8  # 80% for training, 20% for testing
NUM_VAL_EPOCHS = 20
BATCH_SIZE = 100
NUM_FOLDS = 5  # Number of folds for cross-validation
HID_SIZE = 200

finetune = True

# %%
if len(additional_columns) == 0:
    model_version = "basic"
elif len(additional_columns) == 1:
    model_version = "ease"
else:
    model_version = "full"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## 3.3) Splitting data into train and test sets

# %%
# Get all keys and shuffle them
keys = list(user_dict.keys())
random.shuffle(keys)

# Split keys into train and test
split_index = int(len(keys) * train_ratio)
train_keys = keys[:split_index]
test_keys = keys[split_index:]

# Create train and test dictionaries
train_dict = {key: user_dict[key] for key in train_keys}
test_dict = {key: user_dict[key] for key in test_keys}

# %% [markdown]
# ## 3.4) Hyperparameter-tuning

# %% [markdown]
# ### 3.4.1) Parameters learning rate, embedding dimension, number of hidden layers and dropout probability

# %%
train_keys = list(train_dict.keys())

pseudo_train_keys, val_keys = split(train_keys)

pseudo_train_dict = {key: train_dict[key] for key in pseudo_train_keys}
pseudo_train_dict = dict(sorted(pseudo_train_dict.items(), key=lambda item: len(item[1])))

val_dict = {key: train_dict[key] for key in val_keys}
val_dict = dict(sorted(val_dict.items(), key=lambda item: len(item[1])))

pseudo_train_dataset = SequenceDataset(pseudo_train_dict)
pseudo_train_loader = DataLoader(pseudo_train_dataset, batch_size=BATCH_SIZE, collate_fn=collate_batch, pin_memory=True, num_workers=0)

val_dataset = SequenceDataset(val_dict)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, collate_fn=collate_batch, pin_memory=True, num_workers=0)

NUM_EPOCHS = 10


if finetune:

  columns = ["learning_rate", "embed_dim", "num_hid_layers", "drop_prob", "hid_size",
           "final_train_loss", "final_train_auc", "final_val_loss", "final_val_auc"]
  results_df = pd.DataFrame(columns=columns)

  configs = [
    {
        "learning_rate": lr,
        "model_params": {
            "num_skills": NUM_SKILLS,
            "num_other": NUM_OTHER,
            "embed_dim": embed_dim,
            "hid_size": hid_size,
            "num_hid_layers": num_hid_layers,
            "drop_prob": drop_prob
        },
    }
    for lr in [1e-1] # stay as 1e-2
    for embed_dim in [3, 5, 7]
    for num_hid_layers in [1, 2] # stay as one
    for drop_prob in [0.5]  # try 0.5 and 0.3
    for hid_size in [100, 150, 200] # try 200 and 500
    ]

  for idx, config in enumerate(configs, 1):
      log_message = f"\nEvaluating Config {idx}/{len(configs)}"
      print(log_message)  # Print to console

      lr = config["learning_rate"]
      model_params = config["model_params"]
      embed_dim = model_params["embed_dim"]
      num_hid_layers = model_params["num_hid_layers"]
      drop_prob = model_params["drop_prob"]
      hid_size = model_params["hid_size"]

      model, list_train_loss, list_train_auc, list_val_loss, list_val_auc = train_dkt(
          model_params, lr, NUM_EPOCHS, device, pseudo_train_loader, val_loader, 3
          )

          # Record the results
      new_row = pd.DataFrame([{
          "learning_rate": lr,
          "embed_dim": embed_dim,
          "num_hid_layers": num_hid_layers,
          "drop_prob": drop_prob,
          "hid_size": hid_size,
          "final_train_loss": list_train_loss[-1],
          "final_train_auc": list_train_auc[-1],
          "final_val_loss": list_val_loss[-1],
          "final_val_auc": list_val_auc[-1]
      }])

      # Concatenate the new row to the existing DataFrame
      results_df = pd.concat([results_df, new_row], ignore_index=True)

else:
  # Load the configuration from the JSON file
  with open('dkt_best_config.json', 'r') as f:
      best_config = json.load(f)
      best_config['model_params']['num_other'] = 1 + len(additional_columns)
      best_config['model_params']['embed_dim'] = 10
# Out:
# Evaluating Config 1/18
# Training: 100%|██████████| 11/11 [00:00<00:00, 34.56 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 44.82 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 40.78 batches/s]
# For the 1. epoch train AUC is 0.7839088630470363, train loss is 0.5238127355436677.
# Training: 100%|██████████| 11/11 [00:00<00:00, 35.84 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 44.18 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 48.61 batches/s]
# For the 2. epoch train AUC is 0.8201076787043804, train loss is 0.4829598396148497.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.17 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 44.87 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 49.52 batches/s]
# For the 3. epoch train AUC is 0.8256555010022123, train loss is 0.47179344788338373.
# Training: 100%|██████████| 11/11 [00:00<00:00, 34.81 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.49 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 50.56 batches/s]
# For the 4. epoch train AUC is 0.8372751778802374, train loss is 0.45989510735261785.
# Training: 100%|██████████| 11/11 [00:00<00:00, 34.35 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 45.73 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 45.93 batches/s]
# For the 5. epoch train AUC is 0.8399350465589123, train loss is 0.4573069799293592.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.20 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.78 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 45.86 batches/s]
# For the 6. epoch train AUC is 0.8435848138172994, train loss is 0.4534288071891637.
# Training: 100%|██████████| 11/11 [00:00<00:00, 35.15 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.52 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 49.07 batches/s]
# For the 7. epoch train AUC is 0.8494208164246255, train loss is 0.4427718117977809.
# Training: 100%|██████████| 11/11 [00:00<00:00, 33.11 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 44.49 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 48.99 batches/s]
# For the 8. epoch train AUC is 0.8482139194387275, train loss is 0.4455792276025976.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.93 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.69 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.57 batches/s]
# For the 9. epoch train AUC is 0.8511760388393974, train loss is 0.44103308123292273.
# Training: 100%|██████████| 11/11 [00:00<00:00, 35.05 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.86 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 47.58 batches/s]
# <ipython-input-76-eeb36074f270>:74: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results_df = pd.concat([results_df, new_row], ignore_index=True)
# For the 10. epoch train AUC is 0.8548579582041631, train loss is 0.4344354998139502.
#
# Evaluating Config 2/18
# Training: 100%|██████████| 11/11 [00:00<00:00, 22.28 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 23.69 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 25.80 batches/s]
# For the 1. epoch train AUC is 0.8117010683055159, train loss is 0.4933115839958191.
# Training: 100%|██████████| 11/11 [00:00<00:00, 20.88 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 26.58 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 30.53 batches/s]
# For the 2. epoch train AUC is 0.8234918580099275, train loss is 0.47641517757212076.
# Training: 100%|██████████| 11/11 [00:00<00:00, 21.27 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 25.00 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 27.27 batches/s]
# For the 3. epoch train AUC is 0.8336703228748816, train loss is 0.4604091511189359.
# Training: 100%|██████████| 11/11 [00:00<00:00, 20.40 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 36.01 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 49.56 batches/s]
# For the 4. epoch train AUC is 0.8381829294558127, train loss is 0.4549362951690711.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.18 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 46.90 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 40.48 batches/s]
# For the 5. epoch train AUC is 0.843756097216868, train loss is 0.45136612480126537.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.83 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.23 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 26.16 batches/s]
# For the 6. epoch train AUC is 0.8489273270082468, train loss is 0.44688053848674.
# Training: 100%|██████████| 11/11 [00:00<00:00, 18.84 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 19.81 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 45.72 batches/s]
# For the 7. epoch train AUC is 0.8514117574022656, train loss is 0.4416561164323566.
# Training: 100%|██████████| 11/11 [00:00<00:00, 31.97 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 44.92 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 39.20 batches/s]
# For the 8. epoch train AUC is 0.8527319929490792, train loss is 0.43726781647182206.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.21 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.52 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 49.10 batches/s]
# For the 9. epoch train AUC is 0.8557515303284908, train loss is 0.4354829183481272.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.37 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 45.24 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 38.85 batches/s]
# For the 10. epoch train AUC is 0.852048648588743, train loss is 0.4373877849972364.
#
# Evaluating Config 3/18
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.36 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.51 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.52 batches/s]
# For the 1. epoch train AUC is 0.7804987582823846, train loss is 0.523983246782451.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.22 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.83 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 42.97 batches/s]
# For the 2. epoch train AUC is 0.8203579701845812, train loss is 0.48386504464936486.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.09 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 39.69 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.94 batches/s]
# For the 3. epoch train AUC is 0.8320879657158659, train loss is 0.46337899883973943.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.63 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 39.55 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 46.72 batches/s]
# For the 4. epoch train AUC is 0.8351605105105687, train loss is 0.45944008954520366.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.52 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.22 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.65 batches/s]
# For the 5. epoch train AUC is 0.8393199561408349, train loss is 0.45430299639701843.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.71 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.57 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 45.56 batches/s]
# For the 6. epoch train AUC is 0.8454286170258929, train loss is 0.4467726717296156.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.08 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 37.80 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 38.41 batches/s]
# For the 7. epoch train AUC is 0.8481375641646861, train loss is 0.44380446082179986.
# Training: 100%|██████████| 11/11 [00:00<00:00, 19.20 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 24.67 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 27.94 batches/s]
# For the 8. epoch train AUC is 0.8516525999681178, train loss is 0.43949516739660094.
# Training: 100%|██████████| 11/11 [00:00<00:00, 19.92 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 23.13 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 25.42 batches/s]
# For the 9. epoch train AUC is 0.8547821607503593, train loss is 0.4403319497710293.
# Training: 100%|██████████| 11/11 [00:00<00:00, 18.78 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 35.02 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 45.43 batches/s]
# For the 10. epoch train AUC is 0.8546362452022782, train loss is 0.4338564716496514.
#
# Evaluating Config 4/18
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.38 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 39.11 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.75 batches/s]
# For the 1. epoch train AUC is 0.724247803318635, train loss is 0.579728914696036.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.98 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.78 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 46.94 batches/s]
# For the 2. epoch train AUC is 0.8112597915875499, train loss is 0.4928414645125565.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.57 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.72 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 46.97 batches/s]
# For the 3. epoch train AUC is 0.8261272429342306, train loss is 0.4792820791017662.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.84 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 39.80 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 46.64 batches/s]
# For the 4. epoch train AUC is 0.826187595509394, train loss is 0.47732001890256565.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.66 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.04 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 33.65 batches/s]
# For the 5. epoch train AUC is 0.8285671403529936, train loss is 0.4685458063500599.
# Training: 100%|██████████| 11/11 [00:00<00:00, 31.24 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.20 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 48.34 batches/s]
# For the 6. epoch train AUC is 0.8331211238172449, train loss is 0.46372604022905667.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.10 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.38 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.87 batches/s]
# For the 7. epoch train AUC is 0.8355788121258612, train loss is 0.4662039939639638.
# Training: 100%|██████████| 11/11 [00:00<00:00, 31.65 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 39.38 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 45.62 batches/s]
# For the 8. epoch train AUC is 0.8422961469406463, train loss is 0.4539153408078314.
# Training: 100%|██████████| 11/11 [00:00<00:00, 31.16 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.81 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 47.28 batches/s]
# For the 9. epoch train AUC is 0.8403762352410336, train loss is 0.4634590970659719.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.70 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.69 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 47.27 batches/s]
# For the 10. epoch train AUC is 0.8486398916047311, train loss is 0.4459808144754576.
#
# Evaluating Config 5/18
# Training: 100%|██████████| 11/11 [00:00<00:00, 27.80 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.12 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 45.56 batches/s]
# For the 1. epoch train AUC is 0.7135015879050403, train loss is 0.5765471713056842.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.56 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.70 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 47.03 batches/s]
# For the 2. epoch train AUC is 0.8139134335427932, train loss is 0.488084203988603.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.88 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.66 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 46.68 batches/s]
# For the 3. epoch train AUC is 0.8246875816368547, train loss is 0.47373465831997325.
# Training: 100%|██████████| 11/11 [00:00<00:00, 24.90 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 26.25 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 24.78 batches/s]
# For the 4. epoch train AUC is 0.8314278757332694, train loss is 0.46354052337627966.
# Training: 100%|██████████| 11/11 [00:00<00:00, 19.14 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 25.85 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 28.03 batches/s]
# For the 5. epoch train AUC is 0.8343232866204904, train loss is 0.4603538307750109.
# Training: 100%|██████████| 11/11 [00:00<00:00, 17.59 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 24.71 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 25.02 batches/s]
# For the 6. epoch train AUC is 0.8391708573067304, train loss is 0.4553408208981301.
# Training: 100%|██████████| 11/11 [00:00<00:00, 25.04 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.73 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.94 batches/s]
# For the 7. epoch train AUC is 0.8450530091575809, train loss is 0.45257440701271723.
# Training: 100%|██████████| 11/11 [00:00<00:00, 27.58 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 37.92 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 45.38 batches/s]
# For the 8. epoch train AUC is 0.8468696059434708, train loss is 0.45938139922410537.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.37 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.44 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.64 batches/s]
# For the 9. epoch train AUC is 0.8469604643193742, train loss is 0.454470829188245.
# Training: 100%|██████████| 11/11 [00:00<00:00, 26.85 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.98 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.55 batches/s]
# For the 10. epoch train AUC is 0.8486085221339918, train loss is 0.4439856080175604.
#
# Evaluating Config 6/18
# Training: 100%|██████████| 11/11 [00:00<00:00, 27.48 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.32 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 35.66 batches/s]
# For the 1. epoch train AUC is 0.6046432136340557, train loss is 0.7693020915522158.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.85 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 39.97 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 41.91 batches/s]
# For the 2. epoch train AUC is 0.5702128431091619, train loss is 0.7927486421992478.
# Training: 100%|██████████| 11/11 [00:00<00:00, 27.87 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.30 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 42.84 batches/s]
# For the 3. epoch train AUC is 0.6090738904818997, train loss is 0.6959523888467585.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.63 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.29 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 45.24 batches/s]
# For the 4. epoch train AUC is 0.6596044649683652, train loss is 0.6304889471785536.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.43 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.30 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 37.97 batches/s]
# For the 5. epoch train AUC is 0.6747568012097132, train loss is 0.6103105307782738.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.23 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.32 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 36.66 batches/s]
# For the 6. epoch train AUC is 0.6685676605136965, train loss is 0.6166727554450915.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.40 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.50 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.12 batches/s]
# For the 7. epoch train AUC is 0.6812521879120494, train loss is 0.6058702445724635.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.75 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.44 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.34 batches/s]
# For the 8. epoch train AUC is 0.6842886744252454, train loss is 0.5901361727020116.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.01 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 39.54 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.25 batches/s]
# For the 9. epoch train AUC is 0.7072709134119051, train loss is 0.5810318473473336.
# Training: 100%|██████████| 11/11 [00:00<00:00, 27.03 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 23.18 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 24.17 batches/s]
# For the 10. epoch train AUC is 0.7022091931586348, train loss is 0.5900545803088586.
#
# Evaluating Config 7/18
# Training: 100%|██████████| 11/11 [00:00<00:00, 21.50 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 24.72 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 25.12 batches/s]
# For the 1. epoch train AUC is 0.7997169574740345, train loss is 0.5060351621178747.
# Training: 100%|██████████| 11/11 [00:00<00:00, 21.11 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 24.16 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 26.30 batches/s]
# For the 2. epoch train AUC is 0.8255480133144962, train loss is 0.473223279112751.
# Training: 100%|██████████| 11/11 [00:00<00:00, 27.83 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 45.77 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.96 batches/s]
# For the 3. epoch train AUC is 0.8285704593399873, train loss is 0.4674022562295488.
# Training: 100%|██████████| 11/11 [00:00<00:00, 34.13 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 45.02 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 46.57 batches/s]
# For the 4. epoch train AUC is 0.8345987180667602, train loss is 0.46303901944345643.
# Training: 100%|██████████| 11/11 [00:00<00:00, 35.24 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.73 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 48.62 batches/s]
# For the 5. epoch train AUC is 0.841759282382077, train loss is 0.4559701686923944.
# Training: 100%|██████████| 11/11 [00:00<00:00, 35.95 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 46.58 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 47.73 batches/s]
# For the 6. epoch train AUC is 0.8444254906723679, train loss is 0.4511064215771203.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.86 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 45.58 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 46.45 batches/s]
# For the 7. epoch train AUC is 0.8471869202661102, train loss is 0.44784061509428674.
# Training: 100%|██████████| 11/11 [00:00<00:00, 34.96 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.03 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 48.10 batches/s]
# For the 8. epoch train AUC is 0.8489168991245984, train loss is 0.4453514273305541.
# Training: 100%|██████████| 11/11 [00:00<00:00, 36.71 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 44.91 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 48.73 batches/s]
# For the 9. epoch train AUC is 0.8522179918575342, train loss is 0.4391251353962908.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.82 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.97 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 40.13 batches/s]
# For the 10. epoch train AUC is 0.8553905187157279, train loss is 0.4322619305073636.
#
# Evaluating Config 8/18
# Training: 100%|██████████| 11/11 [00:00<00:00, 31.03 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 39.74 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 45.04 batches/s]
# For the 1. epoch train AUC is 0.7944091320448962, train loss is 0.523121403548324.
# Training: 100%|██████████| 11/11 [00:00<00:00, 33.14 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 45.28 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 46.77 batches/s]
# For the 2. epoch train AUC is 0.8230879946659647, train loss is 0.4770295252499071.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.62 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 44.54 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 45.21 batches/s]
# For the 3. epoch train AUC is 0.8252643108666555, train loss is 0.4715940804736128.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.21 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 38.15 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 47.77 batches/s]
# For the 4. epoch train AUC is 0.8387808632246039, train loss is 0.4576261926044538.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.00 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.25 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 36.99 batches/s]
# For the 5. epoch train AUC is 0.843767531911757, train loss is 0.45023425371901504.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.89 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.37 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.96 batches/s]
# For the 6. epoch train AUC is 0.8445031838802024, train loss is 0.4518530817286482.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.36 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.74 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 27.53 batches/s]
# For the 7. epoch train AUC is 0.8489708767665856, train loss is 0.44425447646853994.
# Training: 100%|██████████| 11/11 [00:00<00:00, 19.32 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 26.38 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 28.00 batches/s]
# For the 8. epoch train AUC is 0.8545348809473035, train loss is 0.43938451224160424.
# Training: 100%|██████████| 11/11 [00:00<00:00, 20.83 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 25.49 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 25.38 batches/s]
# For the 9. epoch train AUC is 0.8560462472713849, train loss is 0.4335084071437132.
# Training: 100%|██████████| 11/11 [00:00<00:00, 19.96 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 29.14 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 45.91 batches/s]
# For the 10. epoch train AUC is 0.8533239450916769, train loss is 0.4359598165576898.
#
# Evaluating Config 9/18
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.25 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 37.69 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.92 batches/s]
# For the 1. epoch train AUC is 0.6502204679224182, train loss is 0.642394027663666.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.90 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.45 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.69 batches/s]
# For the 2. epoch train AUC is 0.7043114716782585, train loss is 0.5811403897202131.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.74 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.16 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 36.06 batches/s]
# For the 3. epoch train AUC is 0.7956668552189343, train loss is 0.5195642084751314.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.01 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.05 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 45.59 batches/s]
# For the 4. epoch train AUC is 0.8138912518889014, train loss is 0.4908559779519016.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.62 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.70 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 39.84 batches/s]
# For the 5. epoch train AUC is 0.8249838453659456, train loss is 0.47703275431707065.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.34 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 38.02 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 45.94 batches/s]
# For the 6. epoch train AUC is 0.8337693002964331, train loss is 0.4665936552783818.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.09 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.28 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.11 batches/s]
# For the 7. epoch train AUC is 0.8390697172397915, train loss is 0.45764893582723676.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.52 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 38.61 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 40.17 batches/s]
# For the 8. epoch train AUC is 0.8449806498782486, train loss is 0.454670124262282.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.98 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.04 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 46.15 batches/s]
# For the 9. epoch train AUC is 0.8475461795608774, train loss is 0.44480488080422853.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.71 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.15 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 46.48 batches/s]
# For the 10. epoch train AUC is 0.8516508870583404, train loss is 0.43888850756061887.
#
# Evaluating Config 10/18
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.71 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.40 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 42.71 batches/s]
# For the 1. epoch train AUC is 0.72725083666009, train loss is 0.576524393651092.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.74 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.34 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.72 batches/s]
# For the 2. epoch train AUC is 0.8120752988155895, train loss is 0.48998492782555736.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.04 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.93 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 42.75 batches/s]
# For the 3. epoch train AUC is 0.8172348072790981, train loss is 0.480990135843314.
# Training: 100%|██████████| 11/11 [00:00<00:00, 23.80 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 24.93 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 27.67 batches/s]
# For the 4. epoch train AUC is 0.8280815448023048, train loss is 0.47642592290072766.
# Training: 100%|██████████| 11/11 [00:00<00:00, 20.04 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 24.57 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 25.71 batches/s]
# For the 5. epoch train AUC is 0.8306512870410101, train loss is 0.4676965550311561.
# Training: 100%|██████████| 11/11 [00:00<00:00, 18.26 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 23.77 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 23.92 batches/s]
# For the 6. epoch train AUC is 0.8343369913496397, train loss is 0.4659106627251338.
# Training: 100%|██████████| 11/11 [00:00<00:00, 22.93 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.57 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.89 batches/s]
# For the 7. epoch train AUC is 0.8368575184049001, train loss is 0.46483427170410896.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.13 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.71 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 47.02 batches/s]
# For the 8. epoch train AUC is 0.8455100463526092, train loss is 0.4455965557723369.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.72 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 38.88 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 39.35 batches/s]
# For the 9. epoch train AUC is 0.8458001177433129, train loss is 0.4559284153493863.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.84 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.84 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.87 batches/s]
# For the 10. epoch train AUC is 0.8482990966141369, train loss is 0.4398297545979324.
#
# Evaluating Config 11/18
# Training: 100%|██████████| 11/11 [00:00<00:00, 26.91 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 38.39 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.64 batches/s]
# For the 1. epoch train AUC is 0.6318195200449745, train loss is 0.6613628152504708.
# Training: 100%|██████████| 11/11 [00:00<00:00, 27.90 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.49 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.63 batches/s]
# For the 2. epoch train AUC is 0.6838285243481687, train loss is 0.5988072666149695.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.57 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 37.99 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 45.35 batches/s]
# For the 3. epoch train AUC is 0.7488772671232975, train loss is 0.5554960086507704.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.88 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.78 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 41.66 batches/s]
# For the 4. epoch train AUC is 0.8036183981454786, train loss is 0.4967364602297255.
# Training: 100%|██████████| 11/11 [00:00<00:00, 27.28 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.06 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.54 batches/s]
# For the 5. epoch train AUC is 0.823846729362501, train loss is 0.481616600335223.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.49 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.61 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 42.06 batches/s]
# For the 6. epoch train AUC is 0.82451072812739, train loss is 0.4734144271577446.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.65 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.43 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 35.43 batches/s]
# For the 7. epoch train AUC is 0.8325875337602411, train loss is 0.46777878889759766.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.31 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.21 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 41.58 batches/s]
# For the 8. epoch train AUC is 0.8280968850561965, train loss is 0.467629025283369.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.58 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.27 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.18 batches/s]
# For the 9. epoch train AUC is 0.8366352630168354, train loss is 0.45759599041012883.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.14 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 26.79 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 29.22 batches/s]
# For the 10. epoch train AUC is 0.8379097808242502, train loss is 0.46113875450439823.
#
# Evaluating Config 12/18
# Training: 100%|██████████| 11/11 [00:00<00:00, 18.72 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 24.26 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 23.12 batches/s]
# For the 1. epoch train AUC is 0.6134505256100015, train loss is 0.6564131136079436.
# Training: 100%|██████████| 11/11 [00:00<00:00, 18.33 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 22.76 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 25.96 batches/s]
# For the 2. epoch train AUC is 0.6548035148170708, train loss is 0.6255258032419149.
# Training: 100%|██████████| 11/11 [00:00<00:00, 20.09 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.89 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 36.47 batches/s]
# For the 3. epoch train AUC is 0.6530782040385447, train loss is 0.6241231144053264.
# Training: 100%|██████████| 11/11 [00:00<00:00, 27.94 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 38.38 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.25 batches/s]
# For the 4. epoch train AUC is 0.635857848001364, train loss is 0.6300780431738178.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.56 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.48 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 37.58 batches/s]
# For the 5. epoch train AUC is 0.6639955991660457, train loss is 0.6486653147391903.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.63 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 39.61 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 39.92 batches/s]
# For the 6. epoch train AUC is 0.6478878295738343, train loss is 0.621922659642488.
# Training: 100%|██████████| 11/11 [00:00<00:00, 27.48 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.83 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 40.66 batches/s]
# For the 7. epoch train AUC is 0.678339893568791, train loss is 0.5985660061095525.
# Training: 100%|██████████| 11/11 [00:00<00:00, 27.93 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 39.51 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 40.90 batches/s]
# For the 8. epoch train AUC is 0.6484622121711445, train loss is 0.6180726150864536.
# Training: 100%|██████████| 11/11 [00:00<00:00, 26.98 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.03 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 35.15 batches/s]
# For the 9. epoch train AUC is 0.6825904512074289, train loss is 0.601312901209859.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.82 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 38.38 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 36.69 batches/s]
# For the 10. epoch train AUC is 0.6830397233940105, train loss is 0.602981686592102.
#
# Evaluating Config 13/18
# Training: 100%|██████████| 11/11 [00:00<00:00, 33.28 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 44.30 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.62 batches/s]
# For the 1. epoch train AUC is 0.8124497053098411, train loss is 0.4918020928947671.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.84 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.18 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 40.34 batches/s]
# For the 2. epoch train AUC is 0.83284904910827, train loss is 0.4689054222940241.
# Training: 100%|██████████| 11/11 [00:00<00:00, 35.86 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.42 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.90 batches/s]
# For the 3. epoch train AUC is 0.8296732040435614, train loss is 0.4634399625282843.
# Training: 100%|██████████| 11/11 [00:00<00:00, 33.07 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 44.76 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 45.77 batches/s]
# For the 4. epoch train AUC is 0.8388405016651858, train loss is 0.4545301404392835.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.54 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.17 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 46.51 batches/s]
# For the 5. epoch train AUC is 0.8434685934758088, train loss is 0.44955404869561055.
# Training: 100%|██████████| 11/11 [00:00<00:00, 33.70 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.51 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 33.29 batches/s]
# For the 6. epoch train AUC is 0.8451123655117752, train loss is 0.44556836827287394.
# Training: 100%|██████████| 11/11 [00:00<00:00, 21.59 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 25.59 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 31.29 batches/s]
# For the 7. epoch train AUC is 0.8471721802340312, train loss is 0.44294126404141915.
# Training: 100%|██████████| 11/11 [00:00<00:00, 22.55 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 25.52 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 26.69 batches/s]
# For the 8. epoch train AUC is 0.8538261906110444, train loss is 0.4394578476553982.
# Training: 100%|██████████| 11/11 [00:00<00:00, 19.99 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 31.54 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.46 batches/s]
# For the 9. epoch train AUC is 0.8552434047234855, train loss is 0.4326940158617149.
# Training: 100%|██████████| 11/11 [00:00<00:00, 34.22 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 44.61 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 36.52 batches/s]
# For the 10. epoch train AUC is 0.8554995316242471, train loss is 0.43359335099609153.
#
# Evaluating Config 14/18
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.92 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.39 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 39.89 batches/s]
# For the 1. epoch train AUC is 0.8121932200826166, train loss is 0.49609768998275683.
# Training: 100%|██████████| 11/11 [00:00<00:00, 31.65 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 45.15 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.78 batches/s]
# For the 2. epoch train AUC is 0.8271673770008164, train loss is 0.4719216574742956.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.79 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.44 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 46.14 batches/s]
# For the 3. epoch train AUC is 0.8383288621432478, train loss is 0.45739772742234386.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.82 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.76 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 38.40 batches/s]
# For the 4. epoch train AUC is 0.843922446157208, train loss is 0.45159291410909114.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.70 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.49 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.81 batches/s]
# For the 5. epoch train AUC is 0.8485040319595853, train loss is 0.44332599061206707.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.75 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.89 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.48 batches/s]
# For the 6. epoch train AUC is 0.8472099104624888, train loss is 0.44308339565703014.
# Training: 100%|██████████| 11/11 [00:00<00:00, 31.77 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.85 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.60 batches/s]
# For the 7. epoch train AUC is 0.8528582346864721, train loss is 0.43804562757316146.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.72 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.80 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.38 batches/s]
# For the 8. epoch train AUC is 0.8558809877821615, train loss is 0.43579488385070875.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.36 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.03 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.04 batches/s]
# For the 9. epoch train AUC is 0.8563988982212747, train loss is 0.43136083529990854.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.01 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 37.75 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 41.84 batches/s]
# For the 10. epoch train AUC is 0.8583370420212615, train loss is 0.4317809976999042.
#
# Evaluating Config 15/18
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.29 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.02 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.13 batches/s]
# For the 1. epoch train AUC is 0.7911997932543843, train loss is 0.5171633244139476.
# Training: 100%|██████████| 11/11 [00:00<00:00, 26.96 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.03 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 42.84 batches/s]
# For the 2. epoch train AUC is 0.8208256002403974, train loss is 0.47748692637508355.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.98 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 34.44 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 26.30 batches/s]
# For the 3. epoch train AUC is 0.8293206252940614, train loss is 0.47348210475977187.
# Training: 100%|██████████| 11/11 [00:00<00:00, 20.17 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 25.63 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 28.64 batches/s]
# For the 4. epoch train AUC is 0.8376596174701295, train loss is 0.45581219121090416.
# Training: 100%|██████████| 11/11 [00:00<00:00, 19.46 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 22.99 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 25.15 batches/s]
# For the 5. epoch train AUC is 0.8407857934243261, train loss is 0.4565242048606132.
# Training: 100%|██████████| 11/11 [00:00<00:00, 19.52 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 25.37 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 31.16 batches/s]
# For the 6. epoch train AUC is 0.8474067242593875, train loss is 0.4455591833707198.
# Training: 100%|██████████| 11/11 [00:00<00:00, 26.40 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 37.72 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 42.04 batches/s]
# For the 7. epoch train AUC is 0.8497362847954355, train loss is 0.4423137084372993.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.88 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.28 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 37.98 batches/s]
# For the 8. epoch train AUC is 0.8530944279387765, train loss is 0.437204216869132.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.83 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 37.21 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 42.34 batches/s]
# For the 9. epoch train AUC is 0.8515952909684752, train loss is 0.43552245966439107.
# Training: 100%|██████████| 11/11 [00:00<00:00, 27.71 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.07 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 37.24 batches/s]
# For the 10. epoch train AUC is 0.8587511996548407, train loss is 0.4282050393160107.
#
# Evaluating Config 16/18
# Training: 100%|██████████| 11/11 [00:00<00:00, 26.39 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 37.63 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 41.34 batches/s]
# For the 1. epoch train AUC is 0.7778047880225174, train loss is 0.5285943234429776.
# Training: 100%|██████████| 11/11 [00:00<00:00, 25.94 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.47 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 40.03 batches/s]
# For the 2. epoch train AUC is 0.8174652744135374, train loss is 0.4817846596819683.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.39 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 39.53 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 39.47 batches/s]
# For the 3. epoch train AUC is 0.8299106765110564, train loss is 0.4656268430566325.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.08 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.97 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 34.34 batches/s]
# For the 4. epoch train AUC is 0.8310094788770852, train loss is 0.46140504577784863.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.58 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.64 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 42.59 batches/s]
# For the 5. epoch train AUC is 0.8424039682294564, train loss is 0.45036508620363996.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.77 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 38.84 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.09 batches/s]
# For the 6. epoch train AUC is 0.8450010240097049, train loss is 0.4453187156649469.
# Training: 100%|██████████| 11/11 [00:00<00:00, 27.58 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 39.47 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 42.34 batches/s]
# For the 7. epoch train AUC is 0.8486075850742578, train loss is 0.4450393504309423.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.73 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 37.47 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 38.82 batches/s]
# For the 8. epoch train AUC is 0.8498132359870847, train loss is 0.4386522208602683.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.22 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.98 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 25.74 batches/s]
# For the 9. epoch train AUC is 0.854803090990393, train loss is 0.4347338517314022.
# Training: 100%|██████████| 11/11 [00:00<00:00, 18.48 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 25.80 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 28.75 batches/s]
# For the 10. epoch train AUC is 0.8536603923822881, train loss is 0.43488861548090446.
#
# Evaluating Config 17/18
# Training: 100%|██████████| 11/11 [00:00<00:00, 19.56 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 23.54 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 22.62 batches/s]
# For the 1. epoch train AUC is 0.6536278505396732, train loss is 0.6152806692910426.
# Training: 100%|██████████| 11/11 [00:00<00:00, 16.57 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 25.03 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 40.24 batches/s]
# For the 2. epoch train AUC is 0.7829520501598328, train loss is 0.5230629753719256.
# Training: 100%|██████████| 11/11 [00:00<00:00, 26.19 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 36.88 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 42.89 batches/s]
# For the 3. epoch train AUC is 0.8142939615282337, train loss is 0.48849482009711775.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.01 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 39.41 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 42.81 batches/s]
# For the 4. epoch train AUC is 0.8196719038169943, train loss is 0.48071388509667035.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.51 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 38.23 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 40.51 batches/s]
# For the 5. epoch train AUC is 0.8253429381350352, train loss is 0.47423386342317153.
# Training: 100%|██████████| 11/11 [00:00<00:00, 26.61 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 39.32 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 38.75 batches/s]
# For the 6. epoch train AUC is 0.8336662210847062, train loss is 0.4675944331780221.
# Training: 100%|██████████| 11/11 [00:00<00:00, 26.63 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.18 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 41.85 batches/s]
# For the 7. epoch train AUC is 0.8329430247418785, train loss is 0.4617074849536118.
# Training: 100%|██████████| 11/11 [00:00<00:00, 25.92 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 38.05 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 42.65 batches/s]
# For the 8. epoch train AUC is 0.8404860102110044, train loss is 0.4585541819484488.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.66 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 39.57 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 34.01 batches/s]
# For the 9. epoch train AUC is 0.844513835656136, train loss is 0.44927095874999334.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.78 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.61 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 39.54 batches/s]
# For the 10. epoch train AUC is 0.8404555435227699, train loss is 0.4566618687319524.
#
# Evaluating Config 18/18
# Training: 100%|██████████| 11/11 [00:00<00:00, 26.98 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.21 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 42.58 batches/s]
# For the 1. epoch train AUC is 0.5726366114624082, train loss is 0.7616279258311374.
# Training: 100%|██████████| 11/11 [00:00<00:00, 27.76 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 39.22 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.11 batches/s]
# For the 2. epoch train AUC is 0.6235789641025942, train loss is 0.6774611039069093.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.17 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 37.39 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 42.28 batches/s]
# For the 3. epoch train AUC is 0.6088463494226385, train loss is 0.702026213835744.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.19 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 39.81 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 34.11 batches/s]
# For the 4. epoch train AUC is 0.6146923349926171, train loss is 0.6741371345751493.
# Training: 100%|██████████| 11/11 [00:00<00:00, 26.68 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 24.29 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 23.41 batches/s]
# For the 5. epoch train AUC is 0.6346226349122129, train loss is 0.6456971631466764.
# Training: 100%|██████████| 11/11 [00:00<00:00, 18.04 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 24.93 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 23.68 batches/s]
# For the 6. epoch train AUC is 0.664429450703099, train loss is 0.6266758441925049.
# Training: 100%|██████████| 11/11 [00:00<00:00, 17.90 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 21.53 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 23.61 batches/s]
# For the 7. epoch train AUC is 0.5828095300598004, train loss is 0.6654798261170248.
# Training: 100%|██████████| 11/11 [00:00<00:00, 21.58 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 36.08 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 39.94 batches/s]
# For the 8. epoch train AUC is 0.6553812949227371, train loss is 0.6196698430672433.
# Training: 100%|██████████| 11/11 [00:00<00:00, 27.57 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 36.29 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 33.85 batches/s]
# For the 9. epoch train AUC is 0.6075833440073438, train loss is 0.6569570991599444.
# Early stopping triggered after 9 epochs. No improvement in validation AUC for 3 epochs.

# %% [markdown]
# After thorough hyperparamter-tuning the optimal choices are:

# %%
results_df
# Out:
#     learning_rate embed_dim num_hid_layers  drop_prob hid_size  \
# 0             0.1         3              1        0.5      100
# 1             0.1         3              1        0.5      150
# 2             0.1         3              1        0.5      200
# 3             0.1         3              2        0.5      100
# 4             0.1         3              2        0.5      150
# 5             0.1         3              2        0.5      200
# 6             0.1         5              1        0.5      100
# 7             0.1         5              1        0.5      150
# 8             0.1         5              1        0.5      200
# 9             0.1         5              2        0.5      100
# 10            0.1         5              2        0.5      150
# 11            0.1         5              2        0.5      200
# 12            0.1         7              1        0.5      100
# 13            0.1         7              1        0.5      150
# 14            0.1         7              1        0.5      200
# 15            0.1         7              2        0.5      100
# 16            0.1         7              2        0.5      150
# 17            0.1         7              2        0.5      200
#
#     final_train_loss  final_train_auc  final_val_loss  final_val_auc
# 0           0.434435         0.854858        0.452487       0.848038
# 1           0.437388         0.852049        0.454196       0.847720
# 2           0.433856         0.854636        0.448459       0.849639
# 3           0.445981         0.848640        0.457048       0.847623
# 4           0.443986         0.848609        0.457130       0.845287
# 5           0.590055         0.702209        0.601848       0.700641
# 6           0.432262         0.855391        0.449845       0.849858
# 7           0.435960         0.853324        0.449240       0.849393
# 8           0.438889         0.851651        0.449510       0.849410
# 9           0.439830         0.848299        0.454766       0.844478
# 10          0.461139         0.837910        0.473245       0.832947
# 11          0.602982         0.683040        0.609074       0.687695
# 12          0.433593         0.855500        0.448291       0.849352
# 13          0.431781         0.858337        0.447297       0.853164
# 14          0.428205         0.858751        0.449520       0.851167
# 15          0.434889         0.853660        0.452140       0.848063
# 16          0.456662         0.840456        0.466192       0.837555
# 17          0.656957         0.607583        0.675358       0.607016

# %%
results_df
# Out:
#    learning_rate embed_dim num_hid_layers  drop_prob hid_size  \
# 0           0.01        10              1        0.4      200
# 1           0.01        10              1        0.5      200
# 2           0.01        15              1        0.4      200
# 3           0.01        15              1        0.5      200
# 4           0.01        20              1        0.4      200
# 5           0.01        20              1        0.5      200
#
#    final_train_loss  final_train_auc  final_val_loss  final_val_auc
# 0          0.442386         0.854707        0.491945       0.803830
# 1          0.444032         0.854672        0.492097       0.805930
# 2          0.439261         0.856654        0.489743       0.807031
# 3          0.433709         0.860408        0.487996       0.807049
# 4          0.440104         0.857119        0.491832       0.807466
# 5          0.439785         0.857159        0.490695       0.809669

# %% [markdown]
# ### 3.4.2) Number of epochs

# %%
best_config = {'learning_rate': 0.01,
               'model_params':
               {
            "num_skills": NUM_SKILLS,
            "num_other": NUM_OTHER,
            "embed_dim": 7,
            "hid_size": 150,
            "num_hid_layers": 1,
            "drop_prob": 0.5
            }
               }

# %%
model_params=best_config['model_params']
lr=best_config['learning_rate']

NUM_MAX_EPOCHS = 40

model, list_train_loss, list_train_auc, list_val_loss, list_val_auc = train_dkt(
    model_params, lr, NUM_MAX_EPOCHS, device, pseudo_train_loader, val_loader, None
    )
# Out:
# Training: 100%|██████████| 11/11 [00:00<00:00, 31.76 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.15 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 46.90 batches/s]
# For the 1. epoch train AUC is 0.7312543385388808, train loss is 0.5923915667441285.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.06 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.70 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 42.34 batches/s]
# For the 2. epoch train AUC is 0.7854594373309738, train loss is 0.5395348234084046.
# Training: 100%|██████████| 11/11 [00:00<00:00, 31.94 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.39 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 46.48 batches/s]
# For the 3. epoch train AUC is 0.8008359683635231, train loss is 0.5170622832566789.
# Training: 100%|██████████| 11/11 [00:00<00:00, 31.57 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.20 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.57 batches/s]
# For the 4. epoch train AUC is 0.813097146727527, train loss is 0.49302909935562356.
# Training: 100%|██████████| 11/11 [00:00<00:00, 29.95 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 40.03 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 46.99 batches/s]
# For the 5. epoch train AUC is 0.8234672401843013, train loss is 0.4771155732349285.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.14 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.34 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 40.78 batches/s]
# For the 6. epoch train AUC is 0.830789948668212, train loss is 0.46896170267781007.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.46 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 44.93 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 36.49 batches/s]
# For the 7. epoch train AUC is 0.8337188439045596, train loss is 0.47120655364203223.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.14 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 38.50 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 47.33 batches/s]
# For the 8. epoch train AUC is 0.8393670939482258, train loss is 0.4588238107926637.
# Training: 100%|██████████| 11/11 [00:00<00:00, 31.88 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 44.60 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 46.20 batches/s]
# For the 9. epoch train AUC is 0.8430443125485014, train loss is 0.4544684256164773.
# Training: 100%|██████████| 11/11 [00:00<00:00, 20.23 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 25.69 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 26.69 batches/s]
# For the 10. epoch train AUC is 0.8466162641019642, train loss is 0.4495927407903579.
# Training: 100%|██████████| 11/11 [00:00<00:00, 21.26 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 25.03 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 26.42 batches/s]
# For the 11. epoch train AUC is 0.8516646031848459, train loss is 0.44336644104383527.
# Training: 100%|██████████| 11/11 [00:00<00:00, 19.88 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 25.20 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 47.74 batches/s]
# For the 12. epoch train AUC is 0.8531895816650257, train loss is 0.44254977292227515.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.09 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.37 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 45.06 batches/s]
# For the 13. epoch train AUC is 0.8532237973995692, train loss is 0.4425201181647847.
# Training: 100%|██████████| 11/11 [00:00<00:00, 31.28 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.65 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 47.96 batches/s]
# For the 14. epoch train AUC is 0.8565139007854455, train loss is 0.4397664640134978.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.46 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.51 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 45.66 batches/s]
# For the 15. epoch train AUC is 0.8608340968432274, train loss is 0.4323039867924255.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.82 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.26 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 37.32 batches/s]
# For the 16. epoch train AUC is 0.8612687283556107, train loss is 0.4304533785986669.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.78 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.46 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 48.39 batches/s]
# For the 17. epoch train AUC is 0.8647243669459447, train loss is 0.42667889218885924.
# Training: 100%|██████████| 11/11 [00:00<00:00, 31.15 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 45.04 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 48.12 batches/s]
# For the 18. epoch train AUC is 0.867108787739758, train loss is 0.42198862873234794.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.59 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.09 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 39.89 batches/s]
# For the 19. epoch train AUC is 0.8678090280338998, train loss is 0.4224299088265132.
# Training: 100%|██████████| 11/11 [00:00<00:00, 31.17 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.58 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 47.43 batches/s]
# For the 20. epoch train AUC is 0.8703563307365513, train loss is 0.4185147479321193.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.37 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 45.61 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.99 batches/s]
# For the 21. epoch train AUC is 0.8740995134185923, train loss is 0.412824034401514.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.37 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 37.98 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 43.73 batches/s]
# For the 22. epoch train AUC is 0.8772279626342125, train loss is 0.4081475853341297.
# Training: 100%|██████████| 11/11 [00:00<00:00, 31.19 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 45.16 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 47.32 batches/s]
# For the 23. epoch train AUC is 0.8796169958696374, train loss is 0.4036373568391337.
# Training: 100%|██████████| 11/11 [00:00<00:00, 28.43 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.98 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 46.46 batches/s]
# For the 24. epoch train AUC is 0.8834647374426897, train loss is 0.39842027946583275.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.30 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.33 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 47.33 batches/s]
# For the 25. epoch train AUC is 0.8882946626677175, train loss is 0.3908172958684199.
# Training: 100%|██████████| 11/11 [00:00<00:00, 31.47 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 45.08 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 35.03 batches/s]
# For the 26. epoch train AUC is 0.8906455732869337, train loss is 0.38636591365036455.
# Training: 100%|██████████| 11/11 [00:00<00:00, 23.09 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 26.54 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 22.97 batches/s]
# For the 27. epoch train AUC is 0.8944049318585376, train loss is 0.3809348243532829.
# Training: 100%|██████████| 11/11 [00:00<00:00, 21.48 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 25.23 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 24.99 batches/s]
# For the 28. epoch train AUC is 0.8961715996660484, train loss is 0.3799127296915332.
# Training: 100%|██████████| 11/11 [00:00<00:00, 20.12 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 24.22 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 27.16 batches/s]
# For the 29. epoch train AUC is 0.9005217448503918, train loss is 0.36999889716361334.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.81 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 44.29 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 45.28 batches/s]
# For the 30. epoch train AUC is 0.9037896476488658, train loss is 0.3673264575236052.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.45 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.52 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 46.02 batches/s]
# For the 31. epoch train AUC is 0.9040794671509705, train loss is 0.3656323997719774.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.66 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.12 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 47.29 batches/s]
# For the 32. epoch train AUC is 0.9058240599801052, train loss is 0.3608327484825282.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.71 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.94 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 41.53 batches/s]
# For the 33. epoch train AUC is 0.9124182673972993, train loss is 0.35058048512171774.
# Training: 100%|██████████| 11/11 [00:00<00:00, 31.38 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.91 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.92 batches/s]
# For the 34. epoch train AUC is 0.9153527562645263, train loss is 0.3471132985596518.
# Training: 100%|██████████| 11/11 [00:00<00:00, 30.97 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.70 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 40.99 batches/s]
# For the 35. epoch train AUC is 0.9175276124169383, train loss is 0.3406109387434802.
# Training: 100%|██████████| 11/11 [00:00<00:00, 32.77 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.52 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 47.91 batches/s]
# For the 36. epoch train AUC is 0.9190678321415836, train loss is 0.33684677840436544.
# Training: 100%|██████████| 11/11 [00:00<00:00, 31.72 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 45.18 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.88 batches/s]
# For the 37. epoch train AUC is 0.924361727967012, train loss is 0.3286885124387093.
# Training: 100%|██████████| 11/11 [00:00<00:00, 31.41 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 42.60 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 44.67 batches/s]
# For the 38. epoch train AUC is 0.9276557985934903, train loss is 0.3215013618029437.
# Training: 100%|██████████| 11/11 [00:00<00:00, 33.12 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 41.27 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 49.03 batches/s]
# For the 39. epoch train AUC is 0.9262890703438905, train loss is 0.3234335288260747.
# Training: 100%|██████████| 11/11 [00:00<00:00, 31.66 batches/s]
# Evaluation: 100%|██████████| 11/11 [00:00<00:00, 43.11 batches/s]
# Evaluation: 100%|██████████| 3/3 [00:00<00:00, 41.72 batches/s]
# For the 40. epoch train AUC is 0.931221934307913, train loss is 0.3172347942023601.

# %%
def plot_auc_loss(list_train_loss, list_train_auc, list_val_loss, list_val_auc, num_epochs):
    epochs = range(1, num_epochs + 1)

    # Plot Training and Validation Loss
    plt.figure(figsize=(12, 5))

    # Add a supertitle
    plt.suptitle('With feature Ease', fontsize=16)
    #plt.suptitle('With features Ease, Time spent and Hint used', fontsize=16)

    plt.subplot(1, 2, 1)
    plt.plot(epochs, list_train_loss, label='Training Loss', color='b', linestyle='-', marker='o')
    plt.plot(epochs, list_val_loss, label='Validation Loss', color='r', linestyle='-', marker='o')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # Plot Training and Validation AUC
    plt.subplot(1, 2, 2)
    plt.plot(epochs, list_train_auc, label='Training AUC', color='b', linestyle='-', marker='o')
    plt.plot(epochs, list_val_auc, label='Validation AUC', color='r', linestyle='-', marker='o')
    plt.title('Training and Validation AUC')
    plt.xlabel('Epochs')
    plt.ylabel('AUC')
    plt.legend()

    # Display the plots
    plt.tight_layout()
    plt.show()

# Plot the results
plot_auc_loss(list_train_loss, list_train_auc, list_val_loss, list_val_auc, NUM_MAX_EPOCHS)

# %% [markdown]
# Based on this, we will set the number of training epochs to 11.

# %% [markdown]
# ## 3.5) Model training

# %%
NUM_TRAINING_EPOCHS = 18

# Training on the whole train set
train_dict = dict(sorted(train_dict.items(), key=lambda item: len(item[1])))
train_dataset = SequenceDataset(train_dict)
train_loader = DataLoader(train_dataset, batch_size=100, collate_fn=collate_batch, pin_memory=False, num_workers=0)

test_dict = dict(sorted(test_dict.items(), key=lambda item: len(item[1])))
test_dataset = SequenceDataset(test_dict)
test_loader = DataLoader(test_dataset, batch_size=100, collate_fn=collate_batch, pin_memory=False, num_workers=0)

# Log training details
training_message = "Training on the whole train set"
print(training_message)  # Print to console

best_model, list_train_loss, list_train_auc, list_val_loss, list_val_auc = train_dkt(
    model_params=best_config['model_params'],
    lr=best_config['learning_rate'],
    num_epochs=NUM_TRAINING_EPOCHS,
    device=device,
    train_loader=train_loader,
    patience=None
)
# Out:
# Training on the whole train set
# Training: 100%|██████████| 13/13 [00:00<00:00, 30.18 batches/s]
# Evaluation: 100%|██████████| 13/13 [00:00<00:00, 41.06 batches/s]
# For the 1. epoch train AUC is 0.7493787645004277, train loss is 0.5763065827929456.
# Training: 100%|██████████| 13/13 [00:00<00:00, 27.17 batches/s]
# Evaluation: 100%|██████████| 13/13 [00:00<00:00, 44.40 batches/s]
# For the 2. epoch train AUC is 0.7969747857861786, train loss is 0.5210264898975443.
# Training: 100%|██████████| 13/13 [00:00<00:00, 31.05 batches/s]
# Evaluation: 100%|██████████| 13/13 [00:00<00:00, 43.09 batches/s]
# For the 3. epoch train AUC is 0.8135532901400906, train loss is 0.49408056952568313.
# Training: 100%|██████████| 13/13 [00:00<00:00, 31.63 batches/s]
# Evaluation: 100%|██████████| 13/13 [00:00<00:00, 40.45 batches/s]
# For the 4. epoch train AUC is 0.8237563110097065, train loss is 0.4798894381115896.
# Training: 100%|██████████| 13/13 [00:00<00:00, 21.77 batches/s]
# Evaluation: 100%|██████████| 13/13 [00:00<00:00, 25.43 batches/s]
# For the 5. epoch train AUC is 0.8361820236603245, train loss is 0.4664092436895607.
# Training: 100%|██████████| 13/13 [00:00<00:00, 20.66 batches/s]
# Evaluation: 100%|██████████| 13/13 [00:00<00:00, 23.90 batches/s]
# For the 6. epoch train AUC is 0.8405998579073056, train loss is 0.4592288241993566.
# Training: 100%|██████████| 13/13 [00:00<00:00, 19.75 batches/s]
# Evaluation: 100%|██████████| 13/13 [00:00<00:00, 26.86 batches/s]
# For the 7. epoch train AUC is 0.8423595239153939, train loss is 0.45478021163747917.
# Training: 100%|██████████| 13/13 [00:00<00:00, 31.10 batches/s]
# Evaluation: 100%|██████████| 13/13 [00:00<00:00, 41.29 batches/s]
# For the 8. epoch train AUC is 0.8450106060587228, train loss is 0.4521297222894171.
# Training: 100%|██████████| 13/13 [00:00<00:00, 31.14 batches/s]
# Evaluation: 100%|██████████| 13/13 [00:00<00:00, 40.72 batches/s]
# For the 9. epoch train AUC is 0.8471454142621403, train loss is 0.4514124925647463.
# Training: 100%|██████████| 13/13 [00:00<00:00, 28.29 batches/s]
# Evaluation: 100%|██████████| 13/13 [00:00<00:00, 41.66 batches/s]
# For the 10. epoch train AUC is 0.8526613074905457, train loss is 0.44413430488998107.
# Training: 100%|██████████| 13/13 [00:00<00:00, 30.71 batches/s]
# Evaluation: 100%|██████████| 13/13 [00:00<00:00, 43.96 batches/s]
# For the 11. epoch train AUC is 0.8527534981030622, train loss is 0.4417113246199507.
# Training: 100%|██████████| 13/13 [00:00<00:00, 30.89 batches/s]
# Evaluation: 100%|██████████| 13/13 [00:00<00:00, 40.55 batches/s]
# For the 12. epoch train AUC is 0.8572340481054886, train loss is 0.43595911164461454.
# Training: 100%|██████████| 13/13 [00:00<00:00, 32.42 batches/s]
# Evaluation: 100%|██████████| 13/13 [00:00<00:00, 43.12 batches/s]
# For the 13. epoch train AUC is 0.8595984074397239, train loss is 0.43225320192597666.
# Training: 100%|██████████| 13/13 [00:00<00:00, 30.06 batches/s]
# Evaluation: 100%|██████████| 13/13 [00:00<00:00, 41.87 batches/s]
# For the 14. epoch train AUC is 0.861893275342235, train loss is 0.4293296576842018.
# Training: 100%|██████████| 13/13 [00:00<00:00, 29.76 batches/s]
# Evaluation: 100%|██████████| 13/13 [00:00<00:00, 40.85 batches/s]
# For the 15. epoch train AUC is 0.8629715377683261, train loss is 0.42827889860046575.
# Training: 100%|██████████| 13/13 [00:00<00:00, 31.35 batches/s]
# Evaluation: 100%|██████████| 13/13 [00:00<00:00, 38.72 batches/s]
# For the 16. epoch train AUC is 0.8654909745022411, train loss is 0.42360434815380144.
# Training: 100%|██████████| 13/13 [00:00<00:00, 31.63 batches/s]
# Evaluation: 100%|██████████| 13/13 [00:00<00:00, 43.70 batches/s]
# For the 17. epoch train AUC is 0.8690609697448335, train loss is 0.41760283060695813.
# Training: 100%|██████████| 13/13 [00:00<00:00, 29.07 batches/s]
# Evaluation: 100%|██████████| 13/13 [00:00<00:00, 41.38 batches/s]
# For the 18. epoch train AUC is 0.8706208449542092, train loss is 0.41574171060545845.

# %% [markdown]
# ## 3.6) Model evaluation

# %%
train_loss = list_train_loss[-1]
train_auc = list_train_auc[-1]
test_loss, test_auc = process(best_model, test_loader, device)

# Example results for a model
results = {
    'Dataset': ['Train', 'Test'],
    'AUC': [train_auc, test_auc],
    'Loss': [train_loss, test_loss],
    '#Epochs': [NUM_TRAINING_EPOCHS, None]
}

# Convert to DataFrame
df = pd.DataFrame(results)

print(df)
# Out:
# Evaluation: 100%|██████████| 4/4 [00:00<00:00, 45.17 batches/s]
#   Dataset       AUC      Loss  #Epochs
# 0   Train  0.870621  0.415742     18.0
# 1    Test  0.850332  0.443523      NaN

# %% [markdown]
# ## 3.7) Saving the results

# %%
# Saving the model
model_save_path = f'dkt_{model_version}_model.pth'
torch.save(best_model.state_dict(), model_save_path)
model_save_message = f"Model saved to {model_save_path}"

print(model_save_message)  # Print to console

# Save as CSV
df.to_csv(f'dkt_{model_version}_model_results.csv', index=False)
# Out:
# Model saved to dkt_full_model.pth
