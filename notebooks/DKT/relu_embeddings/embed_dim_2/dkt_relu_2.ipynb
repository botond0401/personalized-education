# %%
import json
import sys
import os
import pandas as pd
import random
import logging
import torch
from torch.utils.data import DataLoader

models_path = os.path.abspath(os.path.join('models'))
sys.path.append(models_path)

src_path = os.path.abspath(os.path.join('src'))
sys.path.append(src_path)

data_path = os.path.abspath(os.path.join('data'))
sys.path.append(data_path)

from data_loader_helper import SequenceDataset, collate_batch
from DKT.dkt_k_fold import k_fold_cv_dkt
from DKT.dkt_train import train_dkt
from KTDataset import KTDataset

# %%
df_answers = pd.read_csv('data/preprocessed/df_answers.csv')
df_skill_names = pd.read_csv('data/preprocessed/df_skill_names.csv')

kt_dataset = KTDataset(df_answers, df_skill_names, prepare_DKT=True)

user_dict = kt_dataset.DKT_datadict
num_skills = kt_dataset.num_skills
num_other = kt_dataset.num_other

# %% [markdown]
# # Set constants

# %%
NUM_EPOCHS = 15
BATCH_SIZE = 100
NUM_FOLDS = 5  # Number of folds for cross-validation
HID_SIZE = 200

embed_dim = 2
special_embed = "relu"

train_ratio = 0.8  # 80% for training, 20% for testing

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Set configs

# %%
configs = [
    {
        "learning_rate": lr,
        "model_params": {
            "num_skills": num_skills,
            "num_other": num_other,
            "embed_dim": embed_dim,
            "hid_size": HID_SIZE,
            "num_hid_layers": num_hid_layers,
            "drop_prob": drop_prob,
            "special_embed": special_embed
        },
    }
    for lr in [1e-3, 1e-4, 1e-5]  # 3 reasonable options for learning rate
    for num_hid_layers in [1, 2]  # Hidden layers 1 or 2
    for drop_prob in [0.3, 0.4, 0.5]  # Dropout rate 0.3, 0.4, 0.5
]

# Example: Printing configurations
for idx, config in enumerate(configs, 1):
    print(f"Config {idx}:\n{config}\n")
# Out:
# Config 1:
# {'learning_rate': 0.001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 2, 'hid_size': 200, 'num_hid_layers': 1, 'drop_prob': 0.3}}
#
# Config 2:
# {'learning_rate': 0.001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 2, 'hid_size': 200, 'num_hid_layers': 1, 'drop_prob': 0.4}}
#
# Config 3:
# {'learning_rate': 0.001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 2, 'hid_size': 200, 'num_hid_layers': 1, 'drop_prob': 0.5}}
#
# Config 4:
# {'learning_rate': 0.001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 2, 'hid_size': 200, 'num_hid_layers': 2, 'drop_prob': 0.3}}
#
# Config 5:
# {'learning_rate': 0.001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 2, 'hid_size': 200, 'num_hid_layers': 2, 'drop_prob': 0.4}}
#
# Config 6:
# {'learning_rate': 0.001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 2, 'hid_size': 200, 'num_hid_layers': 2, 'drop_prob': 0.5}}
#
# Config 7:
# {'learning_rate': 0.0001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 2, 'hid_size': 200, 'num_hid_layers': 1, 'drop_prob': 0.3}}
#
# Config 8:
# {'learning_rate': 0.0001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 2, 'hid_size': 200, 'num_hid_layers': 1, 'drop_prob': 0.4}}
#
# Config 9:
# {'learning_rate': 0.0001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 2, 'hid_size': 200, 'num_hid_layers': 1, 'drop_prob': 0.5}}
#
# Config 10:
# {'learning_rate': 0.0001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 2, 'hid_size': 200, 'num_hid_layers': 2, 'drop_prob': 0.3}}
#
# Config 11:
# {'learning_rate': 0.0001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 2, 'hid_size': 200, 'num_hid_layers': 2, 'drop_prob': 0.4}}
#
# Config 12:
# {'learning_rate': 0.0001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 2, 'hid_size': 200, 'num_hid_layers': 2, 'drop_prob': 0.5}}
#
# Config 13:
# {'learning_rate': 1e-05, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 2, 'hid_size': 200, 'num_hid_layers': 1, 'drop_prob': 0.3}}
#
# Config 14:
# {'learning_rate': 1e-05, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 2, 'hid_size': 200, 'num_hid_layers': 1, 'drop_prob': 0.4}}
#
# Config 15:
# {'learning_rate': 1e-05, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 2, 'hid_size': 200, 'num_hid_layers': 1, 'drop_prob': 0.5}}
#
# Config 16:
# {'learning_rate': 1e-05, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 2, 'hid_size': 200, 'num_hid_layers': 2, 'drop_prob': 0.3}}
#
# Config 17:
# {'learning_rate': 1e-05, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 2, 'hid_size': 200, 'num_hid_layers': 2, 'drop_prob': 0.4}}
#
# Config 18:
# {'learning_rate': 1e-05, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 2, 'hid_size': 200, 'num_hid_layers': 2, 'drop_prob': 0.5}}

# %% [markdown]
# # Split data into train and test sets

# %%
# Get all keys and shuffle them
keys = list(user_dict.keys())
random.shuffle(keys)

# Split keys into train and test
split_index = int(len(keys) * train_ratio)
train_keys = keys[:split_index]
test_keys = keys[split_index:]

# Create train and test dictionaries
train_dict = {key: user_dict[key] for key in train_keys}
test_dict = {key: user_dict[key] for key in test_keys}

# %% [markdown]
# Set up logging

# %%
log_filename = f'model_evaluation_embed_dim_{embed_dim}.log'
logging.basicConfig(filename=log_filename, level=logging.INFO,
                    format='%(asctime)s - %(message)s')

# %% [markdown]
# # Hyperparameter-tuning

# %%
best_val_auc_avg = 0  # Track the best validation AUC
best_config = None  # Track the best configuration

for idx, config in enumerate(configs, 1):
    log_message = f"\nEvaluating Config {idx}/{len(configs)}"
    print(log_message)  # Print to console
    logging.info(log_message)  # Log to file

    lr = config['learning_rate']
    model_params = config['model_params']

    val_auc_avg = k_fold_cv_dkt(
        num_folds=NUM_FOLDS,
        model_params=model_params,
        lr=lr,
        num_epochs=NUM_EPOCHS,
        device=device,
        train_dict=train_dict,
        batch_size=BATCH_SIZE,
        )

    # Update the global best if needed
    if val_auc_avg > best_val_auc_avg:
        best_val_auc_avg = val_auc_avg
        best_config = config  # Save the best configuration
        best_message = f"\nNew best model found: Config {idx}. Validation AUC: {best_val_auc_avg:.4f}"
        print(best_message)  # Print to console
        logging.info(best_message)  # Log to file

# Final output
final_message = f"\nBest test AUC: {best_val_auc_avg:.4f}"
print(final_message)
logging.info(final_message)

final_config_message = f"\nBest Configuration: {best_config}"
print(final_config_message)
logging.info(final_config_message)
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#
# Epoch 8
#
# Training: 24 batches [00:05,  4.44 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.05 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.04 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.32 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  4.87 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  7.06 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.00 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  5.39 batches/s]
# Evaluation: 6 batches [00:01,  4.81 batches/s]
# For the 3. fold AUC is 0.7481911903135536.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  7.15 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.22 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:04,  4.89 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.10 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.03 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:04,  5.69 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.11 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.01 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.93 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  5.05 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.51 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  7.10 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:05,  4.44 batches/s]
# Evaluation: 6 batches [00:00,  6.63 batches/s]
# For the 4. fold AUC is 0.7467330801285005.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.91 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  7.09 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  4.91 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.59 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.17 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.00 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:06,  3.92 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.93 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.13 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.24 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:05,  4.38 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.11 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  7.14 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.60 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:05,  4.70 batches/s]
# Evaluation: 6 batches [00:00,  6.11 batches/s]
# For the 5. fold AUC is 0.7705918090537457.
#
# Evaluating Config 4/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:05,  4.73 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.27 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.93 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.65 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.53 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.09 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  5.71 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  5.12 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.92 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:05,  4.70 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.45 batches/s]
# Evaluation: 6 batches [00:00,  6.36 batches/s]
# For the 1. fold AUC is 0.7773351742532261.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  7.13 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.18 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.16 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.29 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.39 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:04,  5.55 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.47 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.36 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.28 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:05,  4.56 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.27 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.16 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.94 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:05,  4.48 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.22 batches/s]
# Evaluation: 6 batches [00:01,  5.58 batches/s]
# For the 2. fold AUC is 0.7757464240017135.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.97 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:05,  4.75 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.31 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.05 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.71 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.39 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.98 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.01 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  4.94 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.01 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  4.92 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.36 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.91 batches/s]
# Evaluation: 6 batches [00:00,  6.27 batches/s]
# For the 3. fold AUC is 0.7641735541424377.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.64 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.09 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.97 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.98 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.72 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.28 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.85 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.66 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:05,  4.53 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.82 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.87 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  5.42 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.02 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.74 batches/s]
# Evaluation: 6 batches [00:01,  3.92 batches/s]
# For the 4. fold AUC is 0.7613148947044234.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.01 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.03 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:05,  4.75 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.41 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.93 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:04,  5.90 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.05 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.21 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  5.49 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.53 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.97 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.10 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:05,  4.37 batches/s]
# Evaluation: 6 batches [00:00,  6.16 batches/s]
# For the 5. fold AUC is 0.7817035979226957.
#
# New best model found: Config 4. Validation AUC: 0.7721
#
# Evaluating Config 5/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  7.00 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.07 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.48 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.86 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.56 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.43 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.01 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  5.45 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.12 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.93 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:05,  4.35 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.79 batches/s]
# Evaluation: 6 batches [00:00,  6.26 batches/s]
# For the 1. fold AUC is 0.7767058958524936.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  7.04 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.21 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.05 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.03 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.46 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  7.19 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.20 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.63 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  4.92 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.36 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.11 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  5.69 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.63 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.24 batches/s]
# Evaluation: 6 batches [00:01,  5.51 batches/s]
# For the 2. fold AUC is 0.7760524252778195.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.66 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:05,  4.55 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.93 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.00 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:04,  5.54 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:04,  5.30 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.01 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  4.81 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.43 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.91 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.44 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.07 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.92 batches/s]
# Evaluation: 6 batches [00:00,  6.11 batches/s]
# For the 3. fold AUC is 0.766033065543494.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  4.96 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.45 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.80 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.60 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.69 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.98 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.50 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.73 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.92 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:05,  4.26 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.81 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.29 batches/s]
# Evaluation: 6 batches [00:01,  4.11 batches/s]
# For the 4. fold AUC is 0.760036300363465.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.36 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.74 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:05,  4.07 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:04,  4.81 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.87 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:04,  5.12 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.53 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.00 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.80 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:05,  4.46 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.96 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  5.17 batches/s]
# Evaluation: 6 batches [00:00,  6.03 batches/s]
# For the 5. fold AUC is 0.7836147400647899.
#
# New best model found: Config 5. Validation AUC: 0.7725
#
# Evaluating Config 6/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.79 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.85 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:05,  4.32 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.82 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.82 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:04,  5.77 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:04,  5.21 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.97 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.92 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:05,  4.44 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.59 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.97 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.55 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:05,  4.67 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.03 batches/s]
# Evaluation: 6 batches [00:00,  6.52 batches/s]
# For the 1. fold AUC is 0.7763771979086775.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  7.25 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.15 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.67 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.33 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.28 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.49 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  7.29 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.28 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.17 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:05,  4.39 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.15 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.16 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.83 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  4.81 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.17 batches/s]
# Evaluation: 6 batches [00:01,  5.59 batches/s]
# For the 2. fold AUC is 0.7757974552054526.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:05,  4.63 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.55 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.97 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.69 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.50 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.94 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.52 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  5.31 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.01 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.52 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.66 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.93 batches/s]
# Evaluation: 6 batches [00:00,  6.11 batches/s]
# For the 3. fold AUC is 0.7654358918149334.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.66 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.09 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.79 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.64 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.49 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.69 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:05,  4.55 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.72 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.87 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  5.47 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  5.93 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.76 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:05,  4.44 batches/s]
# Evaluation: 6 batches [00:01,  3.94 batches/s]
# For the 4. fold AUC is 0.7598091919820648.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.29 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:05,  4.48 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.04 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:04,  5.75 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.24 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.85 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:05,  4.75 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.55 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.81 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.92 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:05,  4.49 batches/s]
# Evaluation: 6 batches [00:00,  6.00 batches/s]
# For the 5. fold AUC is 0.7820165939638564.
#
# Evaluating Config 7/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  7.10 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.98 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.02 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.56 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.01 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.05 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.46 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.07 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.93 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.03 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  4.93 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.06 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.94 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.17 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.76 batches/s]
# Evaluation: 6 batches [00:00,  6.48 batches/s]
# For the 1. fold AUC is 0.6732376593017783.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  7.26 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.52 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.09 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.25 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.35 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.24 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:04,  5.11 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.26 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.42 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  5.84 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  5.30 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.37 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  7.32 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.54 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.88 batches/s]
# Evaluation: 6 batches [00:01,  5.56 batches/s]
# For the 2. fold AUC is 0.6847630306199061.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  7.15 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.31 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:05,  4.72 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.08 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.04 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:04,  5.58 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.41 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.24 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.17 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:05,  4.36 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.06 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.16 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.64 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  4.82 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.24 batches/s]
# Evaluation: 6 batches [00:00,  6.20 batches/s]
# For the 3. fold AUC is 0.6807018402201495.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  7.05 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:05,  4.72 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.65 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.42 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  7.07 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.12 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.01 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  4.89 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  5.03 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:05,  4.23 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.05 batches/s]
# Evaluation: 6 batches [00:00,  6.61 batches/s]
# For the 4. fold AUC is 0.6802577057837569.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:05,  4.74 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.73 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.14 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.20 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.40 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.18 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  7.19 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.60 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:05,  4.70 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.21 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.17 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  5.93 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  5.08 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.14 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.05 batches/s]
# Evaluation: 6 batches [00:00,  6.05 batches/s]
# For the 5. fold AUC is 0.6971198978302233.
#
# Evaluating Config 8/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:05,  4.36 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  7.06 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.47 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:04,  4.88 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.08 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  7.05 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.57 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.39 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.05 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:05,  4.37 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  7.05 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.08 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.04 batches/s]
# Evaluation: 6 batches [00:01,  4.05 batches/s]
# For the 1. fold AUC is 0.6798168696952257.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.73 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  7.43 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.49 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:05,  4.47 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.27 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.37 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  7.14 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:05,  4.54 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.26 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.32 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.51 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  5.14 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  7.40 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.33 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  5.93 batches/s]
# Evaluation: 6 batches [00:01,  3.16 batches/s]
# For the 2. fold AUC is 0.6887757612571549.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.73 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.92 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.14 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:05,  4.65 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.18 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.17 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.27 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.00 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.94 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.05 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  5.29 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.55 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  7.13 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.19 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:05,  4.68 batches/s]
# Evaluation: 6 batches [00:00,  6.19 batches/s]
# For the 3. fold AUC is 0.6759490197490106.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.91 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.82 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  4.98 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.68 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.94 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.94 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.39 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.06 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.85 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  5.60 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  5.30 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.13 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.40 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.04 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.11 batches/s]
# Evaluation: 6 batches [00:00,  6.65 batches/s]
# For the 4. fold AUC is 0.6736212095923518.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.91 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:05,  4.33 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.03 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.13 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.34 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:04,  4.82 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  7.21 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.97 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.73 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  5.25 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.03 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.09 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  5.18 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.69 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.13 batches/s]
# Evaluation: 6 batches [00:00,  6.07 batches/s]
# For the 5. fold AUC is 0.6928686849330715.
#
# Evaluating Config 9/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.82 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.19 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.13 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.09 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:04,  5.23 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.61 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.86 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.98 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:05,  4.38 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.15 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.08 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  4.91 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.09 batches/s]
# Evaluation: 6 batches [00:00,  6.51 batches/s]
# For the 1. fold AUC is 0.6695453370361557.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:05,  4.69 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.91 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.29 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.41 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.47 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.34 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  7.25 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.34 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:05,  4.34 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.29 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.29 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.75 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  4.92 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.28 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.26 batches/s]
# Evaluation: 6 batches [00:01,  5.53 batches/s]
# For the 2. fold AUC is 0.687490526195765.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.03 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.55 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.17 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.01 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.64 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.93 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.97 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.67 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.44 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.16 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.07 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  5.05 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.72 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.14 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.77 batches/s]
# Evaluation: 6 batches [00:01,  3.62 batches/s]
# For the 3. fold AUC is 0.6765439341974665.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.21 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.93 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.06 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:05,  4.79 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.62 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:05,  4.38 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.86 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  5.45 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:06,  3.50 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  5.32 batches/s]
# Evaluation: 6 batches [00:01,  4.87 batches/s]
# For the 4. fold AUC is 0.6773658034887861.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  7.08 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  7.03 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.49 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:05,  4.71 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:04,  5.74 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.24 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.11 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  5.05 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.64 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  7.12 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.12 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:05,  4.30 batches/s]
# Evaluation: 6 batches [00:00,  6.03 batches/s]
# For the 5. fold AUC is 0.6936975884379174.
#
# Evaluating Config 10/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.81 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:05,  4.64 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.47 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.35 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.41 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  5.62 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  5.04 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.91 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:05,  4.69 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.35 batches/s]
# Evaluation: 6 batches [00:00,  6.27 batches/s]
# For the 1. fold AUC is 0.6922402504463245.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  7.16 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.93 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  4.95 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.21 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.22 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:04,  5.43 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.47 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.09 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.16 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:05,  4.47 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.30 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.31 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.80 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:05,  4.49 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.12 batches/s]
# Evaluation: 6 batches [00:01,  5.55 batches/s]
# For the 2. fold AUC is 0.7021575185942962.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:05,  4.67 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.44 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.64 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.40 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.94 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.83 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.51 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  5.86 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.80 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.28 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.94 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.03 batches/s]
# Evaluation: 6 batches [00:00,  6.02 batches/s]
# For the 3. fold AUC is 0.690099835389506.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.14 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.40 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.83 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.63 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.45 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.71 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.77 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.12 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:06,  3.89 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.71 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  5.42 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  5.84 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.79 batches/s]
# Evaluation: 6 batches [00:01,  4.37 batches/s]
# For the 4. fold AUC is 0.6817067846206021.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.02 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.93 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:04,  4.89 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.40 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.70 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:05,  4.52 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  5.77 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  5.22 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.83 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  4.88 batches/s]
# Evaluation: 6 batches [00:01,  4.97 batches/s]
# For the 5. fold AUC is 0.7060625864882218.
#
# Evaluating Config 11/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.54 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:04,  5.21 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.64 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.86 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.45 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.67 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.03 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.66 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:05,  4.46 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.65 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.37 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.41 batches/s]
# Evaluation: 6 batches [00:00,  6.21 batches/s]
# For the 1. fold AUC is 0.6911306033130648.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  7.04 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.13 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.08 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.04 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.20 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:04,  5.43 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.66 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.17 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.14 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:05,  4.46 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.09 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.59 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:05,  4.71 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.08 batches/s]
# Evaluation: 6 batches [00:01,  5.48 batches/s]
# For the 2. fold AUC is 0.6964564759159271.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.83 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  4.85 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.38 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.64 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.49 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.44 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.24 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.67 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.48 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.94 batches/s]
# Evaluation: 6 batches [00:00,  6.05 batches/s]
# For the 3. fold AUC is 0.6957353110618815.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:05,  4.60 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.21 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.74 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.10 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.31 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:04,  4.89 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.25 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:05,  4.56 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.86 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.92 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  5.11 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.36 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.93 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.60 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:05,  4.51 batches/s]
# Evaluation: 6 batches [00:00,  6.44 batches/s]
# For the 4. fold AUC is 0.6865277182467345.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.91 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  4.95 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.56 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.07 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.32 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.05 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  4.90 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.06 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.26 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.40 batches/s]
# Evaluation: 6 batches [00:00,  6.03 batches/s]
# For the 5. fold AUC is 0.6999724274675277.
#
# Evaluating Config 12/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.69 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.43 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.24 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.00 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.72 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.45 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.82 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.26 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:05,  4.66 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.85 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.80 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  5.28 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.41 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.91 batches/s]
# Evaluation: 6 batches [00:00,  6.24 batches/s]
# For the 1. fold AUC is 0.6688776153057573.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.16 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  4.82 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.10 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.05 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:04,  5.52 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.29 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  7.19 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.03 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:05,  4.42 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.11 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.04 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.50 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.14 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.02 batches/s]
# Evaluation: 6 batches [00:01,  5.53 batches/s]
# For the 2. fold AUC is 0.6959992511406446.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  4.89 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.29 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.61 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.43 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.68 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.42 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.12 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.87 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.01 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:05,  4.30 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.86 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  5.89 batches/s]
# Evaluation: 6 batches [00:01,  3.94 batches/s]
# For the 3. fold AUC is 0.6929895298424732.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.30 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.75 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.33 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:06,  3.68 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.21 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.60 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:05,  4.46 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.71 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.82 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  5.48 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  5.11 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.76 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:05,  4.23 batches/s]
# Evaluation: 6 batches [00:00,  6.39 batches/s]
# For the 4. fold AUC is 0.6887436521076177.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.80 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.82 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.34 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.35 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.01 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.86 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.37 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.98 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  5.63 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  5.30 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.97 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.97 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:05,  4.67 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.41 batches/s]
# Evaluation: 6 batches [00:01,  5.91 batches/s]
# For the 5. fold AUC is 0.6961148534586573.
#
# Evaluating Config 13/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.83 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.62 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.11 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.87 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.97 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.60 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.32 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:05,  4.49 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.97 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.87 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  5.83 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.15 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.11 batches/s]
# Evaluation: 6 batches [00:00,  6.21 batches/s]
# For the 1. fold AUC is 0.5359076789572136.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  7.29 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:05,  4.50 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.01 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.32 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.08 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.53 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  7.13 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.22 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.82 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:05,  4.68 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.26 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.21 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.18 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.06 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.03 batches/s]
# Evaluation: 6 batches [00:01,  5.36 batches/s]
# For the 2. fold AUC is 0.5362300028568244.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:05,  4.71 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.14 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.73 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.77 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.81 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.25 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.20 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.91 batches/s]
#
# Epoch 12
#
# ...
#
# Training: 24 batches [00:03,  6.86 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.85 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.46 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  5.11 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.92 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.48 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.49 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.97 batches/s]
# Evaluation: 6 batches [00:00,  6.42 batches/s]
# For the 4. fold AUC is 0.5144677734019998.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.60 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.07 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.83 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:04,  5.07 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.58 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.98 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:05,  4.39 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.12 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.12 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.22 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.74 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.09 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.04 batches/s]
# Evaluation: 6 batches [00:00,  6.06 batches/s]
# For the 5. fold AUC is 0.5332222765618985.
#
# Evaluating Config 16/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:05,  4.22 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.71 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.74 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:04,  5.85 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.72 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.67 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.73 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  4.92 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.34 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.81 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.51 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  4.80 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.82 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  5.19 batches/s]
# Evaluation: 6 batches [00:01,  4.82 batches/s]
# For the 1. fold AUC is 0.5617880670121932.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  7.03 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.00 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:04,  5.04 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.00 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:04,  5.07 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.60 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:05,  4.38 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.20 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  7.19 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.57 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:05,  4.78 batches/s]
# Evaluation: 6 batches [00:01,  5.37 batches/s]
# For the 2. fold AUC is 0.5620569111474424.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.79 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:05,  4.40 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.70 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.69 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.42 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.81 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.85 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  5.28 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.25 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:05,  4.41 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  4.93 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.14 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.71 batches/s]
# Evaluation: 6 batches [00:01,  5.99 batches/s]
# For the 3. fold AUC is 0.5459556940598155.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.08 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.18 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.80 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.50 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.51 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.58 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.83 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.30 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.18 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.83 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.69 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:05,  4.36 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.64 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  5.17 batches/s]
# Evaluation: 6 batches [00:01,  5.02 batches/s]
# For the 4. fold AUC is 0.5891911548672065.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.71 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.85 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.50 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:04,  4.99 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.93 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.62 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.57 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.63 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:05,  4.44 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.83 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.65 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.41 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.22 batches/s]
# Evaluation: 6 batches [00:01,  5.92 batches/s]
# For the 5. fold AUC is 0.5636212569976964.
#
# Evaluating Config 17/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.51 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  4.87 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.69 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.66 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.64 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.48 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.36 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:05,  4.58 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.65 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  5.23 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.35 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.66 batches/s]
# Evaluation: 6 batches [00:00,  6.18 batches/s]
# For the 1. fold AUC is 0.5910297727724297.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.68 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.07 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.20 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.83 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:04,  5.07 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.44 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  7.13 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.14 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:05,  4.39 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.01 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.00 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.05 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  4.85 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.97 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.85 batches/s]
# Evaluation: 6 batches [00:01,  5.45 batches/s]
# For the 2. fold AUC is 0.5719899997768825.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:05,  4.35 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.94 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:04,  5.60 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.80 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.48 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.45 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:05,  4.24 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:05,  4.34 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.15 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:05,  4.54 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.33 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.92 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.59 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:05,  4.44 batches/s]
# Evaluation: 6 batches [00:00,  6.06 batches/s]
# For the 3. fold AUC is 0.5725105019269934.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.72 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.50 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:05,  4.42 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.54 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.24 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.56 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.76 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.74 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  4.92 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.25 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.81 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.46 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:05,  4.40 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.78 batches/s]
# Evaluation: 6 batches [00:00,  6.37 batches/s]
# For the 4. fold AUC is 0.52590121335024.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.63 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:05,  4.66 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.48 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.79 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.43 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.87 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.91 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.54 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  4.87 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.66 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.39 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.74 batches/s]
# Evaluation: 6 batches [00:01,  5.98 batches/s]
# For the 5. fold AUC is 0.5714600660082753.
#
# Evaluating Config 18/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.14 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.75 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.45 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:04,  5.85 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.69 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.11 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.12 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:06,  3.99 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.10 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.08 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:05,  4.03 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  5.62 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.76 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  4.85 batches/s]
# Evaluation: 6 batches [00:00,  6.19 batches/s]
# For the 1. fold AUC is 0.5807306315813799.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  7.14 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  7.11 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:05,  4.46 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.07 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.09 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.73 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.60 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.15 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.14 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.22 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  4.97 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.17 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  7.05 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.45 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.45 batches/s]
# Evaluation: 6 batches [00:01,  5.49 batches/s]
# For the 2. fold AUC is 0.5363069236010184.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.44 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.04 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.76 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:04,  5.61 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:06,  3.75 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.44 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.43 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:05,  4.49 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.87 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  5.31 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.99 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.85 batches/s]
# Evaluation: 6 batches [00:00,  6.06 batches/s]
# For the 3. fold AUC is 0.5671726114070103.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.78 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:05,  4.77 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.38 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.50 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.48 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.03 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.51 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.67 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.01 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.52 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.51 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:05,  4.77 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.21 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.76 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.54 batches/s]
# Evaluation: 6 batches [00:01,  3.80 batches/s]
# For the 4. fold AUC is 0.543454286124626.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.92 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.87 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:05,  4.43 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.79 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:04,  5.74 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.07 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.93 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.86 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:05,  4.70 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.65 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.98 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.58 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:05,  4.77 batches/s]
# Evaluation: 6 batches [00:01,  5.90 batches/s]
# For the 5. fold AUC is 0.5683091229817965.
#
# Best test AUC: 0.7725
#
# Best Configuration: {'learning_rate': 0.001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 2, 'hid_size': 200, 'num_hid_layers': 2, 'drop_prob': 0.4}}

# %%
# Training on the whole train set
train_dict = dict(sorted(train_dict.items(), key=lambda item: len(item[1])))
train_dataset = SequenceDataset(train_dict)
train_loader = DataLoader(train_dataset, batch_size=100, collate_fn=collate_batch, pin_memory=True, num_workers=2)

test_dict = dict(sorted(test_dict.items(), key=lambda item: len(item[1])))
test_dataset = SequenceDataset(test_dict)
test_loader = DataLoader(test_dataset, batch_size=100, collate_fn=collate_batch, pin_memory=True, num_workers=2)

# Log training details
training_message = "Training on the whole train set"
print(training_message)  # Print to console
logging.info(training_message)  # Log to file

best_model, test_auc = train_dkt(
    model_params=best_config['model_params'],
    lr=best_config['learning_rate'],
    num_epochs=NUM_EPOCHS,
    device=device,
    train_loader=train_loader,
    val_loader=test_loader
)

# Log test AUC
test_auc_message = f"The achieved test AUC: {test_auc}"
print(test_auc_message)  # Print to console
logging.info(test_auc_message)  # Log to file

# Saving the best model
model_save_path = f"data/models/best_dkt_model_relu_{embed_dim}.pth"
torch.save(best_model.state_dict(), model_save_path)

model_save_message = f"Best model saved to {model_save_path}"
print(model_save_message)  # Print to console
logging.info(model_save_message)  # Log to file

# Save the best configuration
config_save_path = f"data/models/best_dkt_config_relu_{embed_dim}.json"
with open(config_save_path, "w") as f:
    json.dump(best_config, f, indent=4)

config_save_message = f"Best configuration saved to {config_save_path}"
print(config_save_message)  # Print to console
logging.info(config_save_message)  # Log to file
# Out:
# Training on the whole train set
#
# Epoch 1
#
# Training: 30 batches [00:06,  4.90 batches/s]
#
# Epoch 2
#
# Training: 30 batches [00:04,  7.11 batches/s]
#
# Epoch 3
#
# Training: 30 batches [00:04,  7.09 batches/s]
#
# Epoch 4
#
# Training: 30 batches [00:06,  4.86 batches/s]
#
# Epoch 5
#
# Training: 30 batches [00:04,  6.86 batches/s]
#
# Epoch 6
#
# Training: 30 batches [00:04,  7.03 batches/s]
#
# Epoch 7
#
# Training: 30 batches [00:06,  4.96 batches/s]
#
# Epoch 8
#
# Training: 30 batches [00:04,  6.93 batches/s]
#
# Epoch 9
#
# Training: 30 batches [00:04,  7.13 batches/s]
#
# Epoch 10
#
# Training: 30 batches [00:05,  5.18 batches/s]
#
# Epoch 11
#
# Training: 30 batches [00:04,  6.65 batches/s]
#
# Epoch 12
#
# Training: 30 batches [00:04,  7.09 batches/s]
#
# Epoch 13
#
# Training: 30 batches [00:05,  5.17 batches/s]
#
# Epoch 14
#
# Training: 30 batches [00:05,  5.70 batches/s]
#
# Epoch 15
#
# Training: 30 batches [00:04,  7.10 batches/s]
# Evaluation: 8 batches [00:01,  5.47 batches/s]
# The achieved test AUC: 0.7849840286017558
# Best model saved to best_dkt_model_embed_dim_2.pth
# Best configuration saved to best_dkt_config_embed_dim_2.json

# %% [markdown]
# The achieved AUC with an embedding dimension of 2 is 0.7850, which is far below the 0.87 achieved in the paper.
