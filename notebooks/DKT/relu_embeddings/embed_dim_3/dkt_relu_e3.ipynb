# %%
import json
import sys
import os
import pandas as pd
import random
import logging
import torch
from torch.utils.data import DataLoader

from torch.utils.data import Dataset
from torch.nn.utils.rnn import pad_sequence

from collections import defaultdict
from typing import Union, List

from typing import Dict, Any, Optional, Tuple
from tqdm import tqdm
import torch.nn as nn
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
import torch.nn.functional as F
from sklearn.metrics import roc_auc_score
import numpy as np
from sklearn.model_selection import KFold

# %%
class SequenceDataset(Dataset):
    def __init__(self, user_dict):

      # sorting in order to make apdding more efficient
      self.user_ids = sorted(user_dict.keys(), key=lambda x: len(user_dict[x]))
      self.sequences = [user_dict[user_id] for user_id in self.user_ids]

    def __getitem__(self, indices):
      sequence = self.sequences[indices]
      skill_one_hot_vectors = torch.tensor(np.array([item[0] for item in sequence[:-1]]), dtype=torch.float32)
      if len(sequence[0]) == 2:
          # Convert the list comprehension to a numpy array first, then to a tensor
          additional_features = torch.tensor(np.array([item[1] for item in sequence[:-1]]), dtype=torch.float32)
          additional_features = additional_features.unsqueeze(-1)  # Add the extra dimension
      else:
          # Convert the list comprehension to a numpy array first, then to a tensor
          additional_features = torch.tensor(np.array([list(item[1]) + [item[2]] for item in sequence[:-1]]), dtype=torch.float32)

      # Optimize labels creation
      labels = torch.tensor(np.array([list(item[0]) + [item[-1]] for item in sequence[1:]]), dtype=torch.float32)

      return skill_one_hot_vectors, additional_features, labels

    def __len__(self):
        return len(self.sequences)


# Define collate function
def collate_batch(batch):
    # Unpacking batches into sequences and labels
    skill_one_hot_vectors, additional_features, labels = zip(*batch)  # This will now work as expected

    # Convert sequences to padded tensors
    skill_one_hot_vectors_padded = pad_sequence(skill_one_hot_vectors, batch_first=True, padding_value=0)  # Pad inputs to max length
    additional_features_padded = pad_sequence(additional_features, batch_first=True, padding_value=0)  # Pad targets to max length
    labels_padded = pad_sequence(labels, batch_first=True, padding_value=0)  # Pad targets to max length
    lengths = torch.tensor([len(label) for label in labels])

    return skill_one_hot_vectors_padded, additional_features_padded, labels_padded, lengths

# %%
"""
Assistments Data Processing Script

This script processes the Assistments dataset for Bayesian Knowledge Tracing (BKT) or other
educational analytics tasks. It includes functions to clean, filter, and transform the data,
generate relevant statistics, and save the processed results.

Main Features:
- Filters data based on sequence length and minimum thresholds for problems and skills.
- Converts the dataset into a format suitable for BKT models.
- Saves the processed data and skill dictionary for further analysis.

Functions:
- clean_assistments_data: Cleans and processes the raw dataset.
- return_assistments_dict_bkt: Converts processed data into a BKT-compatible format.
- _save_dataframe: Helper function to save DataFrames and log their status.
"""


class KTDataset():
    def __init__(self,
                 df_answers,
                 df_skill_names,
                 renumber_skill_ids=True,
                 prepare_BKT=False,
                 prepare_DKT=False,
                 additional_columns=None):

        self.df_answers = df_answers
        self.df_skill_names = df_skill_names
        self.num_skills = len(df_skill_names)
        self.BKT_datadict = None
        self.DKT_datadict = None
        self.additional_columns = additional_columns
        self.num_other = 1 + (len(additional_columns) if additional_columns is not None else 0)

        if renumber_skill_ids:
            # Map original skill IDs to a continuous range starting from 1
            unique_skill_ids = sorted(df_skill_names['skill_id'].astype(int).unique())
            self.skill_id_mapping = {original_id: new_id for new_id, original_id in enumerate(unique_skill_ids, start=1)}
            # Apply the mapping to create the new column
            df_skill_names['skill_ids_renumbered'] = df_skill_names['skill_id'].map(self.skill_id_mapping)
        else:
            self.skill_id_mapping = None

        if prepare_BKT:
            self.create_BKT_datadict()

        if prepare_DKT:
            self.create_DKT_datadict()


    def return_ordered_ids(self, ids: Union[int, str, List[int], List[str]]) -> Union[int, List[int]]:
        """
        Returns renumbered skill IDs based on the mapping.

        Args:
            ids (Union[int, str, List[int], List[str]]): Original skill ID(s) to be renumbered.

        Returns:
            Union[int, List[int]]: Renumbered skill ID(s).
        """

        if isinstance(ids, (int, str)):
            return self.skill_id_mapping[int(ids)]
        elif isinstance(ids, list):
            return [self.skill_id_mapping[int(id)] for id in ids]
        else:
            raise TypeError("IDs must be an int, str, or a list of int/str.")


    def return_original_ids(self, ids: Union[int, str, List[int], List[str]]) -> Union[int, List[int]]:
        """
        Returns original skill IDs based on the renumbered skill IDs.

        Args:
            ids (Union[int, str, List[int], List[str]]): Renumbered skill ID(s) to be mapped back to the original IDs.

        Returns:
            Union[int, str, List[int], List[str]]: Original skill ID(s).
        """

        if isinstance(ids, (int, str)):
            return self.original_id_mapping.get(int(ids), None)  # Convert to integer for lookup
        elif isinstance(ids, list):
            return [self.original_id_mapping.get(int(id), None) for id in ids]  # Convert each to integer for lookup
        else:
            raise TypeError("IDs must be an int, str, or a list of int/str.")


    def create_BKT_datadict(self):
        """
        Converts Assistments data into a Bayesian Knowledge Tracing (BKT) dictionary.

        Groups data by skill ID and user ID, creating a structure where each skill maps
        to lists of user answer sequences.
        """

        # Create a defaultdict to collect answer sequences per skill
        skill_dict = defaultdict(list)

        for _, row in self.df_skill_names.iterrows():
            skill_id = row['skill_id']
            skill_name = row['skill_name']

            df_answers_filtered = self.df_answers[self.df_answers[str(skill_id)] == 1]
            # Group by user_id and collect sequences of correct answers
            answer_list = df_answers_filtered.groupby('user_id')['correct'].apply(list)

            # Collect all answer sequences for the current skill
            skill_dict[f"{skill_id} ({skill_name})"] = answer_list.tolist()

        # Convert defaultdict to a regular dictionary and return
        self.BKT_datadict = dict(skill_dict)


    def create_DKT_datadict(self):
        """
        Create a DKT dataset with one-hot vectors and additional columns if specified.
        """
        add_col = self.additional_columns

        # Dictionary to hold the data for each user
        dict_skills = defaultdict(list)

        # Iterate over each user group
        for user_id, user_group in self.df_answers.groupby('user_id'):
            # Create a list of tuples for each user's answers
            answer_list = []
            for _, row in user_group.iterrows():
                one_hot_vector = row.iloc[-self.num_skills:].values  # Extract the one-hot vector as an array

                # Collect additional column values as a list
                additional_info = row[add_col].values if add_col else []

                is_correct = row['correct']  # Extract if the answer was correct

                # Append the tuple (one-hot vector, additional info, correct flag)
                if add_col:
                    answer_list.append((one_hot_vector, additional_info, is_correct))
                else:
                    answer_list.append((one_hot_vector, is_correct))

            # Store the answer list in the dictionary under the user ID
            dict_skills[user_id] = answer_list

        self.DKT_datadict = dict(dict_skills)

# %%
# Define the DKT model
class DKT(nn.Module):
    def __init__(self, num_skills, num_other, embed_dim, hid_size, num_hid_layers, drop_prob):
        super(DKT, self).__init__()

        # Custom embedding layer
        self.embedding = nn.Sequential(
            nn.Linear(num_skills, embed_dim),
            nn.Tanh()
            )

        # RNN layer
        self.rnn = nn.LSTM(embed_dim + num_other, hid_size, num_hid_layers, batch_first=True)

        # Dropout layer for regularization
        self.dropout = nn.Dropout(p=drop_prob)

        # Output layer mapping hidden states to probabilities
        self.out = nn.Linear(hid_size, num_skills)

        # Sigmoid for probability output
        self.sigmoid = nn.Sigmoid()

    def forward(self, skills, other, lengths):
        """
        Forward pass for the DKT model.

        Args:
            inputs (Tensor): Input sequence of shape (batch_size, seq_len, 2), where each entry is (problem_id, correct).
            lengths (Tensor): Lengths of sequences (batch_size).

        Returns:
            Tensor: Output probabilities of shape (batch_size, seq_len, num_items).
        """
        # Embed the input sequence
        embedded = self.embedding(skills)

        concatenated = torch.cat((embedded, other), dim=-1)  # (batch_size, seq_length, embed_dim+other_dim)


        # Pack the padded sequence for the RNN
        packed_embedded = pack_padded_sequence(concatenated, lengths, batch_first=True, enforce_sorted=False)

        # RNN processing
        packed_output, _ = self.rnn(packed_embedded)

        # Unpack the sequence
        output, _ = pad_packed_sequence(packed_output, batch_first=True)

        # Apply dropout
        output = self.dropout(output)

        # Output layer for probabilities
        logits = self.out(output)

        # Sigmoid to convert logits to probabilities
        probabilities = self.sigmoid(logits)

        # Mask padded positions
        mask = torch.arange(probabilities.size(1)).expand(len(lengths), probabilities.size(1)) < lengths.unsqueeze(1)
        mask = mask.unsqueeze(-1).expand_as(probabilities)  # Shape: (batch_size, seq_len, num_items)
        mask = mask.to(probabilities.device)
        masked_output = probabilities * mask.float()  # Zero out the padded positions

        return masked_output

# %%
def calculate_DKT_loss(predictions_all, answers_with_labels):
    """
    Calculate the binary cross-entropy loss for a sequence of predictions and labels,
    taking into account the problem ID (task index) for each student.

    Args:
        predictions_all (Tensor): The model's predicted values with shape (batch_size, seq_len, num_skills).
        answers_with_labels (Tensor): Ground truth tensor with shape (batch_size, seq_len, num_skills + 1),
                                     where the last dimension contains problem IDs and correctness labels.
                                     The last element of each entry indicates whether the response was correct (1) or not (0).

    Returns:
        loss (float): The total binary cross-entropy loss for the batch.
    """
    # Extract problem_ids and labels from the inputs
    result, labels = _transform_to_correct_predictions(predictions_all, answers_with_labels)
    # Compute binary cross-entropy loss between the normalized result and the correctness labels
    loss = F.binary_cross_entropy(result, labels)

    return loss


def calculate_auc(predictions_all, answers_with_labels, lengths):
    """
    Calculate the AUC (Area Under the Curve) for a sequence of predictions and labels, considering valid (non-padded) data.

    Args:
        predictions_all (Tensor): The model's predicted values with shape (batch_size, seq_len, num_skills).
        answers_with_labels (Tensor): Ground truth tensor with shape (batch_size, seq_len, num_skills + 1),
                                     where the last element indicates correctness.
        lengths (Tensor): Lengths of sequences for each batch, to ignore padded values.

    Returns:
        auc (float): AUC score for the batch.
    """
    # Extract problem_ids and labels from the inputs
    predictions, labels = _transform_to_correct_predictions(predictions_all, answers_with_labels)

    # Move tensors to CPU and convert to NumPy arrays for AUC calculation
    predictions = predictions.cpu().detach().numpy()  # Move to CPU first
    labels = labels.cpu().detach().numpy()  # Same for labels
    lengths = lengths.cpu().detach().numpy()

    # Create mask to ignore padded values based on sequence lengths
    mask = np.arange(predictions.shape[1])[None, :] < lengths[:, None]  # Shape: (batch_size, seq_len)

    # Apply mask to filter valid predictions and labels
    masked_predictions = np.where(mask, predictions, np.nan)  # Set padded positions to np.nan
    masked_labels = np.where(mask, labels, np.nan)  # Set padded positions to np.nan

    # Flatten the arrays to compute AUC only on non-padded data
    flattened_predictions = masked_predictions[~np.isnan(masked_predictions)]
    flattened_labels = masked_labels[~np.isnan(masked_labels)]

    # Calculate AUC if valid data is present
    if flattened_predictions.size > 0 and flattened_labels.size > 0:
        auc = roc_auc_score(flattened_labels, flattened_predictions)
    else:
        auc = float('nan')  # Return NaN if no valid data for AUC calculation

    return auc


# Assuming test_loader is your DataLoader for the test set
def evaluate_auc(model, test_loader, device):
    model.eval()  # Set the model to evaluation mode
    auc_scores = []

    with torch.no_grad():  # Disable gradient computation for evaluation
        for skill_sequences, other_sequences, answers, lengths in test_loader:
            # Move inputs and answers to the correct device (GPU/CPU)
            skill_sequences = skill_sequences.to(device)
            other_sequences = other_sequences.to(device)
            answers = answers.to(device)
            lengths = lengths.to('cpu')

            # Forward pass through the model
            predictions = model(skill_sequences, other_sequences, lengths)  # Shape (batch_size, seq_len, num_items)

            # Calculate AUC for the current batch
            auc = calculate_auc(predictions, answers, lengths)
            auc_scores.append(auc)

    # Calculate the average AUC over all batches
    average_auc = sum(auc_scores) / len(auc_scores)
    return average_auc


def _transform_to_correct_predictions(predictions_all, answers_with_labels):
    # Extract problem IDs (skills) and correctness labels from the inputs
    problem_ids = answers_with_labels[..., :-1]  # Shape: (batch_size, seq_len, num_skills)
    labels = answers_with_labels[..., -1]   # Shape: (batch_size, seq_len)

    # Element-wise multiplication of predictions and problem IDs to select relevant predictions
    product = predictions_all * problem_ids  # Shape: (batch_size, seq_len, num_skills)

    # Sum over the skill dimension to aggregate predictions for each sequence step
    result_sum = product.sum(dim=2)  # Shape: (batch_size, seq_len)

    # Count the number of relevant skills (ones) for each step to use as a normalization factor
    num_ones = problem_ids.sum(dim=2)  # Shape: (batch_size, seq_len)

    # Avoid division by zero by adding a small constant to the normalization factor
    normalization_factor = num_ones + 1e-8  # Adding a small constant for numerical stability

    # Normalize the summed result by the number of ones (relevant skills)
    result = result_sum / normalization_factor  # Shape: (batch_size, seq_len)

    return result, labels

# %%
def process(model, loader, device, optim=None):
    """
    Process the data in the given loader for either training or evaluation.

    Args:
        model: The model to be used for predictions.
        loader: The DataLoader providing the data.
        optim: The optimizer (if training).

    Returns:
    """
    # Set model to training or evaluation mode
    if optim is not None:
        model.train()
        desc = 'Training'
    else:
        model.eval()
        desc = 'Evaluation'

    losses = []
    auc_scores = []

    with torch.no_grad() if optim is None else torch.enable_grad():

      # Iterate through the DataLoader with tqdm for progress tracking
      for _, (skill_sequences, other_sequences, labels, lengths) in tqdm(enumerate(loader),
                                                          file=sys.stdout,
                                                          unit=' batches',
                                                          desc=desc):
          # Move sequences and labels to the appropriate device
          skill_sequences = skill_sequences.to(device)
          other_sequences = other_sequences.to(device)
          labels = labels.to(device)
          lengths = lengths.to('cpu')

          # Forward pass
          outputs = model(skill_sequences, other_sequences, lengths)
          loss = calculate_DKT_loss(outputs, labels)
          auc = calculate_auc(outputs, labels, lengths)

          if optim is not None:  # Only during training
              optim.zero_grad()  # Reset gradients
              loss.backward()  # Backpropagation
              optim.step()  # Update parameters
              torch.cuda.empty_cache()

          losses.append(loss.item())  # Accumulate loss
          auc_scores.append(auc)  # Accumulate loss

    return sum(losses), sum(auc_scores) / len(auc_scores)


def train_dkt(
    model_params: Dict[str, Any],
    lr: float,
    num_epochs: int,
    device: torch.device,
    train_loader: DataLoader,
    val_loader: Optional[DataLoader] = None
) -> Tuple[torch.nn.Module, float]:
    """
    Trains a Deep Knowledge Tracing (DKT) model using the provided parameters.

    Args:
        model_params (dict): A dictionary of model parameters to initialize the DKT model.
        lr (float): Learning rate for the optimizer.
        num_epochs (int): Number of epochs to train the model.
        device (torch.device): The device (e.g., 'cuda' or 'cpu') to run the training on.
        train_loader (DataLoader): DataLoader for the training dataset.
        val_loader (Optional[DataLoader]): DataLoader for the validation dataset. If None,
                                           training data is used for evaluation.

    Returns:
        Tuple[torch.nn.Module, float]: The trained DKT model and the best validation AUC achieved.

    Notes:
        - If `val_loader` is not provided, the training data is used for evaluation, which may
          lead to overestimation of the performance.
    """
    # Initialize the model and move it to the specified device
    model = DKT(**model_params).to(device)

    # Initialize the optimizer with the model's parameters and specified learning rate
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    # Training loop for the specified number of epochs
    for epoch in range(1, num_epochs + 1):
        print(f"\nEpoch {epoch}\n")

        # Training phase: Update the model using the training data
        process(model, train_loader, device, optimizer)

    # Validation phase: Evaluate the model on the validation dataset (if provided)
    if val_loader is not None:
        _, val_auc = process(model, val_loader, device)
    else:
        # Use training data for evaluation if no validation DataLoader is provided
        print("No validation loader provided. Using training data for evaluation.")
        _, val_auc = process(model, train_loader, device)

    # Return the trained model and the best validation AUC achieved
    return model, val_auc

# %%
def k_fold_cv_dkt(
    num_folds,
    model_params: Dict[str, Any],
    lr: float,
    num_epochs: int,
    device: torch.device,
    train_dict: Dict[int, Any],
    batch_size: int = 100,
    num_workers: int = 2
) -> float:
    """
    Perform k-fold cross-validation for the Deep Knowledge Tracing (DKT) model.

    Args:
        num_folds (int): Number of folds for cross-validation.
        model_params (Dict[str, Any]): Parameters for initializing the DKT model.
        lr (float): Learning rate for the optimizer.
        num_epochs (int): Number of epochs for training in each fold.
        device (torch.device): The device (e.g., 'cuda' or 'cpu') to run the training on.
        train_dict (Dict[int, Any]): Dictionary mapping keys to data for training.
        batch_size (int, optional): Batch size for training and validation. Defaults to 100.
        num_workers (int, optional): Number of subprocesses to use for data loading. Defaults to 2.

    Returns:
        float: The average validation AUC across all folds.

    Notes:
        - Assumes that the `train_dict` keys can be split into train and validation sets.
        - Requires an `AnswerSet` dataset and the `train_dkt` training function.
    """
    kf = KFold(n_splits=num_folds, shuffle=True, random_state=42)

    train_keys = list(train_dict.keys())

    val_auc_list = []

    for fold, (fold_train_idx, fold_val_idx) in enumerate(kf.split(train_keys)):
        print(f"\nFold {fold+1}/{num_folds}")
        fold_train_keys = [train_keys[i] for i in fold_train_idx]
        fold_val_keys = [train_keys[i] for i in fold_val_idx]

        fold_train_dict = {key: train_dict[key] for key in fold_train_keys}
        fold_train_dict = dict(sorted(fold_train_dict.items(), key=lambda item: len(item[1])))

        fold_val_dict = {key: train_dict[key] for key in fold_val_keys}
        fold_val_dict = dict(sorted(fold_val_dict.items(), key=lambda item: len(item[1])))

        fold_train_dataset = SequenceDataset(fold_train_dict)
        fold_train_loader = DataLoader(fold_train_dataset, batch_size=batch_size, collate_fn=collate_batch, pin_memory=True, num_workers=num_workers)

        fold_val_dataset = SequenceDataset(fold_val_dict)
        fold_val_loader = DataLoader(fold_val_dataset, batch_size=batch_size, collate_fn=collate_batch, pin_memory=True, num_workers=num_workers)

        _, val_auc = train_dkt(
            model_params, lr, num_epochs, device,
            fold_train_loader, fold_val_loader
            )

        val_auc_list.append(val_auc)
        print(f'For the {fold+1}. fold AUC is {val_auc}.')

    val_auc_avg = sum(val_auc_list) / num_folds

    return val_auc_avg

# %%
df_answers = pd.read_csv('df_answers.csv')
df_skill_names = pd.read_csv('df_skill_names.csv')

kt_dataset = KTDataset(df_answers, df_skill_names, prepare_DKT=True)

user_dict = kt_dataset.DKT_datadict
num_skills = kt_dataset.num_skills
num_other = kt_dataset.num_other

# %% [markdown]
# # Set constants

# %%
NUM_EPOCHS = 15
BATCH_SIZE = 100
NUM_FOLDS = 5  # Number of folds for cross-validation
HID_SIZE = 200

embed_dim = 3
special_embed = "relu"

train_ratio = 0.8  # 80% for training, 20% for testing

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Set configs

# %%
configs = [
    {
        "learning_rate": lr,
        "model_params": {
            "num_skills": num_skills,
            "num_other": num_other,
            "embed_dim": embed_dim,
            "hid_size": HID_SIZE,
            "num_hid_layers": num_hid_layers,
            "drop_prob": drop_prob,
            "special_embed": special_embed
        },
    }
    for lr in [1e-3, 1e-4, 1e-5]  # 3 reasonable options for learning rate
    for num_hid_layers in [1, 2]  # Hidden layers 1 or 2
    for drop_prob in [0.3, 0.4, 0.5]  # Dropout rate 0.3, 0.4, 0.5
]

# Example: Printing configurations
for idx, config in enumerate(configs, 1):
    print(f"Config {idx}:\n{config}\n")
# Out:
# Config 1:
# {'learning_rate': 0.001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 3, 'hid_size': 200, 'num_hid_layers': 1, 'drop_prob': 0.3}}
#
# Config 2:
# {'learning_rate': 0.001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 3, 'hid_size': 200, 'num_hid_layers': 1, 'drop_prob': 0.4}}
#
# Config 3:
# {'learning_rate': 0.001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 3, 'hid_size': 200, 'num_hid_layers': 1, 'drop_prob': 0.5}}
#
# Config 4:
# {'learning_rate': 0.001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 3, 'hid_size': 200, 'num_hid_layers': 2, 'drop_prob': 0.3}}
#
# Config 5:
# {'learning_rate': 0.001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 3, 'hid_size': 200, 'num_hid_layers': 2, 'drop_prob': 0.4}}
#
# Config 6:
# {'learning_rate': 0.001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 3, 'hid_size': 200, 'num_hid_layers': 2, 'drop_prob': 0.5}}
#
# Config 7:
# {'learning_rate': 0.0001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 3, 'hid_size': 200, 'num_hid_layers': 1, 'drop_prob': 0.3}}
#
# Config 8:
# {'learning_rate': 0.0001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 3, 'hid_size': 200, 'num_hid_layers': 1, 'drop_prob': 0.4}}
#
# Config 9:
# {'learning_rate': 0.0001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 3, 'hid_size': 200, 'num_hid_layers': 1, 'drop_prob': 0.5}}
#
# Config 10:
# {'learning_rate': 0.0001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 3, 'hid_size': 200, 'num_hid_layers': 2, 'drop_prob': 0.3}}
#
# Config 11:
# {'learning_rate': 0.0001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 3, 'hid_size': 200, 'num_hid_layers': 2, 'drop_prob': 0.4}}
#
# Config 12:
# {'learning_rate': 0.0001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 3, 'hid_size': 200, 'num_hid_layers': 2, 'drop_prob': 0.5}}
#
# Config 13:
# {'learning_rate': 1e-05, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 3, 'hid_size': 200, 'num_hid_layers': 1, 'drop_prob': 0.3}}
#
# Config 14:
# {'learning_rate': 1e-05, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 3, 'hid_size': 200, 'num_hid_layers': 1, 'drop_prob': 0.4}}
#
# Config 15:
# {'learning_rate': 1e-05, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 3, 'hid_size': 200, 'num_hid_layers': 1, 'drop_prob': 0.5}}
#
# Config 16:
# {'learning_rate': 1e-05, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 3, 'hid_size': 200, 'num_hid_layers': 2, 'drop_prob': 0.3}}
#
# Config 17:
# {'learning_rate': 1e-05, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 3, 'hid_size': 200, 'num_hid_layers': 2, 'drop_prob': 0.4}}
#
# Config 18:
# {'learning_rate': 1e-05, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 3, 'hid_size': 200, 'num_hid_layers': 2, 'drop_prob': 0.5}}

# %% [markdown]
# # Split data into train and test sets

# %%
# Get all keys and shuffle them
keys = list(user_dict.keys())
random.shuffle(keys)

# Split keys into train and test
split_index = int(len(keys) * train_ratio)
train_keys = keys[:split_index]
test_keys = keys[split_index:]

# Create train and test dictionaries
train_dict = {key: user_dict[key] for key in train_keys}
test_dict = {key: user_dict[key] for key in test_keys}

# %% [markdown]
# Set up logging

# %%
log_filename = f'model_evaluation_embed_dim_{embed_dim}.log'
logging.basicConfig(filename=log_filename, level=logging.INFO,
                    format='%(asctime)s - %(message)s')

# %% [markdown]
# # Hyperparameter-tuning

# %%
best_val_auc_avg = 0  # Track the best validation AUC
best_config = None  # Track the best configuration

for idx, config in enumerate(configs, 1):
    log_message = f"\nEvaluating Config {idx}/{len(configs)}"
    print(log_message)  # Print to console
    logging.info(log_message)  # Log to file

    lr = config['learning_rate']
    model_params = config['model_params']

    val_auc_avg = k_fold_cv_dkt(
        num_folds=NUM_FOLDS,
        model_params=model_params,
        lr=lr,
        num_epochs=NUM_EPOCHS,
        device=device,
        train_dict=train_dict,
        batch_size=BATCH_SIZE,
        )

    # Update the global best if needed
    if val_auc_avg > best_val_auc_avg:
        best_val_auc_avg = val_auc_avg
        best_config = config  # Save the best configuration
        best_message = f"\nNew best model found: Config {idx}. Validation AUC: {best_val_auc_avg:.4f}"
        print(best_message)  # Print to console
        logging.info(best_message)  # Log to file

# Final output
final_message = f"\nBest test AUC: {best_val_auc_avg:.4f}"
print(final_message)
logging.info(final_message)

final_config_message = f"\nBest Configuration: {best_config}"
print(final_config_message)
logging.info(final_config_message)
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.98 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.83 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  5.13 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.12 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  5.17 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.67 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.11 batches/s]
# Evaluation: 6 batches [00:00,  6.00 batches/s]
# For the 3. fold AUC is 0.7585241363549139.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.32 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.26 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.11 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.24 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:04,  5.60 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:04,  5.52 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  7.23 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.28 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.40 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.61 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.26 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.19 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.34 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.30 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.21 batches/s]
# Evaluation: 6 batches [00:01,  5.94 batches/s]
# For the 4. fold AUC is 0.7673333594628361.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.74 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.12 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.12 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.05 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:04,  5.19 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.75 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  7.13 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.00 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:05,  4.49 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.94 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.08 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.15 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.79 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.08 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.03 batches/s]
# Evaluation: 6 batches [00:00,  6.43 batches/s]
# For the 5. fold AUC is 0.75529125229781.
#
# Evaluating Config 4/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:05,  4.58 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.63 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.67 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.65 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.92 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.58 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.06 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.04 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:05,  4.38 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.87 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.08 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  5.95 batches/s]
# Evaluation: 6 batches [00:01,  3.87 batches/s]
# For the 1. fold AUC is 0.7702251101816205.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  7.00 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.91 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:05,  4.56 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.92 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.07 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:04,  5.89 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.07 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.24 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  5.22 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.80 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.86 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.03 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:05,  4.51 batches/s]
# Evaluation: 6 batches [00:01,  5.68 batches/s]
# For the 2. fold AUC is 0.773534872485301.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  7.06 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  4.86 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.54 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.81 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.64 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.77 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  5.55 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.14 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.87 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.75 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:05,  4.38 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.98 batches/s]
# Evaluation: 6 batches [00:00,  6.03 batches/s]
# For the 3. fold AUC is 0.7741513129855605.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.92 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  4.83 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.54 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.91 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.73 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.54 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.01 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.56 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.24 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.12 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.70 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.46 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.04 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.04 batches/s]
# Evaluation: 6 batches [00:00,  6.06 batches/s]
# For the 4. fold AUC is 0.7732778191456862.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:05,  4.62 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.42 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.32 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.67 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.98 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.32 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.44 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.72 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:05,  4.47 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.86 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  5.55 batches/s]
# Evaluation: 6 batches [00:01,  3.56 batches/s]
# For the 5. fold AUC is 0.766076490862885.
#
# New best model found: Config 4. Validation AUC: 0.7715
#
# Evaluating Config 5/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.46 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.92 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.68 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:05,  4.57 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.05 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.07 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  4.84 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.07 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.98 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  5.28 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.37 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  7.09 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.85 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:05,  4.42 batches/s]
# Evaluation: 6 batches [00:00,  6.07 batches/s]
# For the 1. fold AUC is 0.770058512457513.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.20 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.49 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.23 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.15 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.46 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.00 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.14 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.03 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  5.03 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.06 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  7.08 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.30 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.59 batches/s]
# Evaluation: 6 batches [00:01,  5.62 batches/s]
# For the 2. fold AUC is 0.7747357533666973.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.76 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.79 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  4.89 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:04,  5.10 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.55 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.92 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.82 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:05,  4.45 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.77 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.92 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  5.68 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.04 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.80 batches/s]
# Evaluation: 6 batches [00:00,  6.08 batches/s]
# For the 3. fold AUC is 0.7790547302060117.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.85 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:05,  4.38 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:04,  5.86 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:04,  5.38 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.98 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.05 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  4.93 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.64 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.77 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.01 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.33 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.01 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.94 batches/s]
# Evaluation: 6 batches [00:01,  5.85 batches/s]
# For the 4. fold AUC is 0.7747407012721345.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.03 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.63 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.67 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.64 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.47 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.52 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.09 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.75 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.98 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:05,  4.71 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.58 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.47 batches/s]
# Evaluation: 6 batches [00:01,  4.04 batches/s]
# For the 5. fold AUC is 0.7747545220955536.
#
# New best model found: Config 5. Validation AUC: 0.7747
#
# Evaluating Config 6/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.24 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:05,  4.33 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.85 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.83 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:04,  5.71 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  4.93 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.10 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.81 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  4.90 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.57 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.97 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:05,  4.36 batches/s]
# Evaluation: 6 batches [00:00,  6.01 batches/s]
# For the 1. fold AUC is 0.7687495729045892.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.81 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  4.84 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.59 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.00 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.05 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.31 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.01 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.10 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  5.04 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.15 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  4.98 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.68 batches/s]
# Evaluation: 6 batches [00:01,  5.74 batches/s]
# For the 2. fold AUC is 0.7742612185250831.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.63 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.00 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.83 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.79 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.61 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.91 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.73 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:05,  4.49 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.08 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.04 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  5.68 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.00 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.05 batches/s]
# Evaluation: 6 batches [00:00,  6.04 batches/s]
# For the 3. fold AUC is 0.7765936162890009.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:05,  4.36 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.06 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:04,  5.85 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:04,  5.02 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  7.14 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.93 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.08 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.56 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.17 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.79 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.38 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.16 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.84 batches/s]
# Evaluation: 6 batches [00:00,  6.03 batches/s]
# For the 4. fold AUC is 0.7716325185050685.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  4.94 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.19 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.91 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.40 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.50 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.87 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.94 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.10 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.29 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.82 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:05,  4.39 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.91 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.91 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  5.72 batches/s]
# Evaluation: 6 batches [00:01,  3.85 batches/s]
# For the 5. fold AUC is 0.7735480364305268.
#
# Evaluating Config 7/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.71 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:05,  4.47 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.13 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.07 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:04,  5.94 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  4.89 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.09 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.01 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  5.36 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.49 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  7.15 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:05,  4.26 batches/s]
# Evaluation: 6 batches [00:00,  6.20 batches/s]
# For the 1. fold AUC is 0.693055642339489.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  7.34 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  7.24 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.64 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.33 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.14 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.20 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.51 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.80 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.19 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.06 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:05,  4.48 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.12 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  7.07 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.28 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:05,  4.76 batches/s]
# Evaluation: 6 batches [00:01,  5.67 batches/s]
# For the 2. fold AUC is 0.673995765891549.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  7.07 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  7.14 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  4.89 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.58 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.05 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.17 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.45 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.16 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.29 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:05,  4.80 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  7.09 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.30 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.39 batches/s]
# Evaluation: 6 batches [00:00,  6.01 batches/s]
# For the 3. fold AUC is 0.6916106143580665.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  7.08 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.02 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.19 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.15 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:04,  5.10 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.67 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.07 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.09 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:05,  4.32 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.15 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.08 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.54 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  4.91 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.99 batches/s]
# Evaluation: 6 batches [00:01,  5.87 batches/s]
# For the 4. fold AUC is 0.690035852297858.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:05,  4.58 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.75 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.94 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.34 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.80 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.92 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.58 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  5.10 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.93 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.62 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.73 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.88 batches/s]
# Evaluation: 6 batches [00:00,  6.16 batches/s]
# For the 5. fold AUC is 0.6803078422985264.
#
# Evaluating Config 8/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.71 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.11 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.13 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.04 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:04,  5.21 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.56 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.80 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:05,  4.46 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.11 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.01 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  5.75 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  5.04 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.94 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.05 batches/s]
# Evaluation: 6 batches [00:01,  5.96 batches/s]
# For the 1. fold AUC is 0.6897857523368138.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:05,  4.54 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  7.09 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.23 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.70 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.70 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.16 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.77 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.32 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.18 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.15 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  5.34 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.80 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.15 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.98 batches/s]
# Evaluation: 6 batches [00:01,  3.58 batches/s]
# For the 2. fold AUC is 0.6699118062283721.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:06,  3.87 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.97 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.67 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:05,  4.68 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.03 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.69 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:04,  5.54 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.61 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.16 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.08 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:05,  4.41 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.94 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.56 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  5.31 batches/s]
# Evaluation: 6 batches [00:00,  6.02 batches/s]
# For the 3. fold AUC is 0.6931574401803603.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  7.06 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:05,  4.60 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.05 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.13 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:04,  5.62 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:04,  5.34 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.08 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.98 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  4.95 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.63 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.03 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  7.03 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:05,  4.46 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.08 batches/s]
# Evaluation: 6 batches [00:01,  5.66 batches/s]
# For the 4. fold AUC is 0.6868100909346889.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.20 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.36 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.03 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.94 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.39 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.06 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.56 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  5.10 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.87 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  4.94 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.53 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.95 batches/s]
# Evaluation: 6 batches [00:00,  6.25 batches/s]
# For the 5. fold AUC is 0.6847279986856698.
#
# Evaluating Config 9/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.03 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  4.93 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.01 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:04,  5.20 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.62 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:05,  4.45 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.06 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.97 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  5.90 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  4.93 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.07 batches/s]
# Evaluation: 6 batches [00:00,  6.08 batches/s]
# For the 1. fold AUC is 0.6915080584655674.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:05,  4.60 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.28 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.18 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.41 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.09 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  7.20 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.64 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:05,  4.63 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.24 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.20 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.38 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.78 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.11 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.07 batches/s]
# Evaluation: 6 batches [00:01,  5.69 batches/s]
# For the 2. fold AUC is 0.6800855704645197.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:05,  4.63 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.60 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.12 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  7.04 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.27 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.00 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  7.00 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.11 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  4.96 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.20 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.13 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  5.35 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.50 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.04 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.95 batches/s]
# Evaluation: 6 batches [00:01,  3.61 batches/s]
# For the 3. fold AUC is 0.693925043654779.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.03 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  7.10 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.01 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:04,  5.00 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.46 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.11 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  7.06 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:05,  4.49 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.17 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.17 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.08 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  4.83 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  7.12 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.18 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  5.53 batches/s]
# Evaluation: 6 batches [00:01,  3.97 batches/s]
# For the 4. fold AUC is 0.686398704030423.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.97 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  7.00 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.03 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:04,  4.84 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.98 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:04,  5.10 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.57 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.92 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:05,  4.57 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.72 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  5.22 batches/s]
# Evaluation: 6 batches [00:00,  6.24 batches/s]
# For the 5. fold AUC is 0.6861503904938152.
#
# Evaluating Config 10/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.70 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.62 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:05,  4.69 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.69 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:04,  5.62 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:04,  5.38 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.92 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:05,  4.60 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.79 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.69 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.10 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  4.89 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.85 batches/s]
# Evaluation: 6 batches [00:00,  6.14 batches/s]
# For the 1. fold AUC is 0.6954218102996489.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.85 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:05,  4.31 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  7.13 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.80 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.38 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.79 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.00 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.43 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.52 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.83 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.82 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.37 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  7.09 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.98 batches/s]
# Evaluation: 6 batches [00:01,  4.90 batches/s]
# For the 2. fold AUC is 0.6811411539717027.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:05,  4.75 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.39 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.72 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.62 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.60 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.93 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.83 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.34 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.37 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.59 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:05,  4.35 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.85 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.91 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  5.40 batches/s]
# Evaluation: 6 batches [00:01,  4.45 batches/s]
# For the 3. fold AUC is 0.6981823235622638.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.62 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:04,  5.15 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  7.08 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:04,  4.98 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.37 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.83 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:05,  4.59 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.81 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.45 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.15 batches/s]
# Evaluation: 6 batches [00:01,  5.90 batches/s]
# For the 4. fold AUC is 0.7063970127570379.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.74 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.66 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.01 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.87 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.83 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:04,  4.86 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.36 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.79 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.52 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:05,  4.79 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.93 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.74 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  5.10 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.40 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.83 batches/s]
# Evaluation: 6 batches [00:00,  6.20 batches/s]
# For the 5. fold AUC is 0.6888005061951062.
#
# Evaluating Config 11/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.37 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.10 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.74 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.59 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.43 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.73 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.35 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.42 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.71 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:05,  4.59 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.87 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.87 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  5.59 batches/s]
# Evaluation: 6 batches [00:01,  3.46 batches/s]
# For the 1. fold AUC is 0.68812616142888.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.55 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.76 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.56 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:05,  4.69 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:04,  5.47 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.17 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  7.11 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:05,  4.38 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.98 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  7.09 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.19 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  4.87 batches/s]
# Evaluation: 6 batches [00:01,  5.59 batches/s]
# For the 2. fold AUC is 0.686771628751275.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.53 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:05,  4.17 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.85 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.81 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:04,  5.95 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.80 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.79 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  4.92 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.45 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.62 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.49 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:05,  4.76 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.87 batches/s]
# Evaluation: 6 batches [00:01,  5.90 batches/s]
# For the 3. fold AUC is 0.7036735190474598.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.76 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:05,  4.32 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.91 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.96 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.41 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.62 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.97 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.91 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.75 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  5.02 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.98 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.98 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  4.97 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.41 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.92 batches/s]
# Evaluation: 6 batches [00:01,  5.38 batches/s]
# For the 4. fold AUC is 0.7052308821548631.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.38 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.86 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.87 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.46 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.71 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.55 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  4.97 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.26 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:05,  4.23 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.15 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.16 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:06,  3.91 batches/s]
# Evaluation: 6 batches [00:01,  4.20 batches/s]
# For the 5. fold AUC is 0.685398117619768.
#
# Evaluating Config 12/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.81 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.98 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.02 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.49 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  7.07 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.80 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.58 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  7.03 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  5.49 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  5.95 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.79 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:05,  4.29 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.93 batches/s]
# Evaluation: 6 batches [00:00,  6.01 batches/s]
# For the 1. fold AUC is 0.6998277099538716.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.16 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.55 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.83 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.94 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.37 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  7.10 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.06 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.11 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  5.06 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  7.07 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.07 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  5.41 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.32 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  7.04 batches/s]
# Evaluation: 6 batches [00:01,  5.71 batches/s]
# For the 2. fold AUC is 0.6954240066233776.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.85 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  4.85 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.80 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.17 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.21 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.38 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.26 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  4.82 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.60 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  5.88 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:05,  4.44 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  5.38 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  5.74 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:05,  4.33 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  5.32 batches/s]
# Evaluation: 6 batches [00:01,  5.72 batches/s]
# For the 3. fold AUC is 0.7097942570851848.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.67 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  4.86 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.38 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.50 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.40 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.85 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.82 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.31 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.04 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.63 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.52 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.41 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.85 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.63 batches/s]
# Evaluation: 6 batches [00:01,  5.54 batches/s]
# For the 4. fold AUC is 0.6999933131895353.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:05,  4.14 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.61 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.32 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:04,  5.63 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:04,  5.16 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.67 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:05,  4.23 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.47 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.48 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  5.75 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  4.98 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.72 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.68 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:05,  4.58 batches/s]
# Evaluation: 6 batches [00:01,  5.43 batches/s]
# For the 5. fold AUC is 0.6990608316543626.
#
# Evaluating Config 13/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.94 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.77 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.50 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:04,  5.96 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.86 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.73 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.35 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.81 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.76 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  5.36 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.30 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.76 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:05,  4.47 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.92 batches/s]
# Evaluation: 6 batches [00:01,  5.81 batches/s]
# For the 1. fold AUC is 0.5655391952177996.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.74 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:05,  4.55 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.66 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.93 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.55 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  7.04 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.62 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  4.88 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.99 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  7.02 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.73 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.42 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.95 batches/s]
# Evaluation: 6 batches [00:01,  5.44 batches/s]
# For the 2. fold AUC is 0.5624585970797289.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.45 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.02 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.89 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.94 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.70 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.49 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.93 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.40 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:05,  4.75 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.85 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  5.18 batches/s]
#
# ...
#
# Training: 24 batches [00:04,  4.89 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.61 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.63 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.48 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:05,  4.72 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.77 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.86 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.05 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.47 batches/s]
# Evaluation: 6 batches [00:01,  5.57 batches/s]
# For the 4. fold AUC is 0.5557232793991285.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.70 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.51 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.02 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.74 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.80 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.31 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.61 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.82 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:05,  4.71 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.65 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  4.85 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.44 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.68 batches/s]
# Evaluation: 6 batches [00:01,  5.92 batches/s]
# For the 5. fold AUC is 0.527845312120987.
#
# Evaluating Config 16/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.32 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.83 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.71 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.45 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.38 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.81 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.65 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.26 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.12 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.70 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.36 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:05,  4.48 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.65 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.68 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:05,  4.79 batches/s]
# Evaluation: 6 batches [00:01,  4.63 batches/s]
# For the 1. fold AUC is 0.5863738836275254.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.79 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.93 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.63 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:04,  5.19 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.86 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.82 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.31 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.86 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.80 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.29 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:05,  4.53 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.61 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.03 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.44 batches/s]
# Evaluation: 6 batches [00:01,  5.31 batches/s]
# For the 2. fold AUC is 0.5634112741055493.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.64 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.19 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.22 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.73 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.51 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.36 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.69 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.68 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:04,  5.06 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.32 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.74 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.32 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.68 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.75 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.68 batches/s]
# Evaluation: 6 batches [00:01,  5.66 batches/s]
# For the 3. fold AUC is 0.5757601124138055.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:05,  4.18 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.70 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.73 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:04,  5.73 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:04,  5.06 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.80 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:05,  4.72 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.47 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.75 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.50 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:05,  4.61 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.62 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.63 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  5.10 batches/s]
# Evaluation: 6 batches [00:01,  4.49 batches/s]
# For the 4. fold AUC is 0.5487161147947862.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.61 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.67 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.23 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.10 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.49 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.07 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.51 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.73 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.72 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:05,  4.79 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.17 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.63 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.04 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:05,  4.70 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.73 batches/s]
# Evaluation: 6 batches [00:01,  5.98 batches/s]
# For the 5. fold AUC is 0.5848862691424072.
#
# Evaluating Config 17/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.52 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:05,  4.24 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.55 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.61 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:04,  5.23 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.08 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.71 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.43 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:05,  4.37 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.59 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.81 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  4.95 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.24 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.74 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.40 batches/s]
# Evaluation: 6 batches [00:01,  3.59 batches/s]
# For the 1. fold AUC is 0.5843337347970784.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.33 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.45 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:05,  4.58 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.91 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.91 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:04,  5.29 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.19 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.40 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:05,  4.51 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.83 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.70 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.23 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.29 batches/s]
# Evaluation: 6 batches [00:01,  5.30 batches/s]
# For the 2. fold AUC is 0.5539289814690447.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.74 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:04,  5.34 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  4.98 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.61 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.58 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:05,  4.36 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.88 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.69 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.05 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:05,  4.70 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.75 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.86 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  4.90 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.26 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.63 batches/s]
# Evaluation: 6 batches [00:01,  5.66 batches/s]
# For the 3. fold AUC is 0.5740920091759517.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:04,  5.14 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.03 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.76 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.58 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:05,  4.48 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.75 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.77 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:04,  5.23 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.15 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.81 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.59 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:05,  4.58 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.70 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  5.34 batches/s]
# Evaluation: 6 batches [00:01,  4.04 batches/s]
# For the 4. fold AUC is 0.5842205092333579.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.34 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.67 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.32 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.09 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.47 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.12 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.47 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.51 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.60 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  4.80 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.30 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.72 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.22 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:05,  4.55 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.60 batches/s]
# Evaluation: 6 batches [00:01,  5.81 batches/s]
# For the 5. fold AUC is 0.5410110506046036.
#
# Evaluating Config 18/18
#
# Fold 1/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.57 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:05,  4.31 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.79 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.72 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:04,  5.48 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:04,  5.01 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.52 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.82 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:05,  4.23 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.75 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  5.78 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:05,  4.71 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.50 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.75 batches/s]
# Evaluation: 6 batches [00:01,  5.05 batches/s]
# For the 1. fold AUC is 0.5836544015125626.
#
# Fold 2/5
#
# Epoch 1
#
# Training: 24 batches [00:05,  4.58 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.78 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.86 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:04,  5.52 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:04,  5.24 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.62 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.85 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:05,  4.32 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.95 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.87 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:04,  6.00 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  5.01 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.80 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.84 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:04,  4.83 batches/s]
# Evaluation: 6 batches [00:01,  4.31 batches/s]
# For the 2. fold AUC is 0.5477841583858795.
#
# Fold 3/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.60 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.65 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:04,  5.18 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.22 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.71 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.33 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:05,  4.71 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.62 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.71 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:04,  4.88 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.24 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.66 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  5.87 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:05,  4.64 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.80 batches/s]
# Evaluation: 6 batches [00:01,  5.67 batches/s]
# For the 3. fold AUC is 0.607435870194327.
#
# Fold 4/5
#
# Epoch 1
#
# Training: 24 batches [00:03,  6.71 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:05,  4.23 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.82 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:03,  6.52 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:04,  5.43 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:04,  5.78 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.80 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:03,  6.63 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:05,  4.26 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.79 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:03,  6.75 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:04,  5.36 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:04,  5.66 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:03,  6.90 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:03,  6.72 batches/s]
# Evaluation: 6 batches [00:01,  4.06 batches/s]
# For the 4. fold AUC is 0.588037151079512.
#
# Fold 5/5
#
# Epoch 1
#
# Training: 24 batches [00:05,  4.58 batches/s]
#
# Epoch 2
#
# Training: 24 batches [00:03,  6.72 batches/s]
#
# Epoch 3
#
# Training: 24 batches [00:03,  6.63 batches/s]
#
# Epoch 4
#
# Training: 24 batches [00:05,  4.51 batches/s]
#
# Epoch 5
#
# Training: 24 batches [00:03,  6.42 batches/s]
#
# Epoch 6
#
# Training: 24 batches [00:03,  6.66 batches/s]
#
# Epoch 7
#
# Training: 24 batches [00:03,  6.20 batches/s]
#
# Epoch 8
#
# Training: 24 batches [00:05,  4.48 batches/s]
#
# Epoch 9
#
# Training: 24 batches [00:03,  6.52 batches/s]
#
# Epoch 10
#
# Training: 24 batches [00:03,  6.46 batches/s]
#
# Epoch 11
#
# Training: 24 batches [00:05,  4.77 batches/s]
#
# Epoch 12
#
# Training: 24 batches [00:03,  6.27 batches/s]
#
# Epoch 13
#
# Training: 24 batches [00:03,  6.59 batches/s]
#
# Epoch 14
#
# Training: 24 batches [00:04,  5.92 batches/s]
#
# Epoch 15
#
# Training: 24 batches [00:05,  4.63 batches/s]
# Evaluation: 6 batches [00:01,  5.81 batches/s]
# For the 5. fold AUC is 0.5897244859818699.
#
# Best test AUC: 0.7747
#
# Best Configuration: {'learning_rate': 0.001, 'models_params': {'num_skills': 109, 'num_other': 1, 'embed_dim': 3, 'hid_size': 200, 'num_hid_layers': 2, 'drop_prob': 0.4}}

# %%
# Training on the whole train set
train_dict = dict(sorted(train_dict.items(), key=lambda item: len(item[1])))
train_dataset = SequenceDataset(train_dict)
train_loader = DataLoader(train_dataset, batch_size=100, collate_fn=collate_batch, pin_memory=True, num_workers=2)

test_dict = dict(sorted(test_dict.items(), key=lambda item: len(item[1])))
test_dataset = SequenceDataset(test_dict)
test_loader = DataLoader(test_dataset, batch_size=100, collate_fn=collate_batch, pin_memory=True, num_workers=2)

# Log training details
training_message = "Training on the whole train set"
print(training_message)  # Print to console
logging.info(training_message)  # Log to file

best_model, test_auc = train_dkt(
    model_params=best_config['models_params'],
    lr=best_config['learning_rate'],
    num_epochs=NUM_EPOCHS,
    device=device,
    train_loader=train_loader,
    val_loader=test_loader
)

# Log test AUC
test_auc_message = f"The achieved test AUC: {test_auc}"
print(test_auc_message)  # Print to console
logging.info(test_auc_message)  # Log to file

# Saving the best model
model_save_path = f"best_dkt_model_embed_dim_{embed_dim}.pth"
torch.save(best_model.state_dict(), model_save_path)
model_save_message = f"Best model saved to {model_save_path}"
print(model_save_message)  # Print to console
logging.info(model_save_message)  # Log to file

# Save the best configuration
config_save_path = f"best_dkt_config_embed_dim_{embed_dim}.json"
with open(config_save_path, "w") as f:
    json.dump(best_config, f, indent=4)

config_save_message = f"Best configuration saved to {config_save_path}"
print(config_save_message)  # Print to console
logging.info(config_save_message)  # Log to file
# Out:
# Training on the whole train set
#
# Epoch 1
#
# Training: 30 batches [00:04,  6.83 batches/s]
#
# Epoch 2
#
# Training: 30 batches [00:05,  5.67 batches/s]
#
# Epoch 3
#
# Training: 30 batches [00:05,  5.55 batches/s]
#
# Epoch 4
#
# Training: 30 batches [00:04,  6.91 batches/s]
#
# Epoch 5
#
# Training: 30 batches [00:05,  5.49 batches/s]
#
# Epoch 6
#
# Training: 30 batches [00:04,  6.59 batches/s]
#
# Epoch 7
#
# Training: 30 batches [00:04,  6.95 batches/s]
#
# Epoch 8
#
# Training: 30 batches [00:06,  4.88 batches/s]
#
# Epoch 9
#
# Training: 30 batches [00:04,  6.61 batches/s]
#
# Epoch 10
#
# Training: 30 batches [00:04,  6.76 batches/s]
#
# Epoch 11
#
# Training: 30 batches [00:06,  4.89 batches/s]
#
# Epoch 12
#
# Training: 30 batches [00:04,  6.77 batches/s]
#
# Epoch 13
#
# Training: 30 batches [00:04,  6.87 batches/s]
#
# Epoch 14
#
# Training: 30 batches [00:06,  4.54 batches/s]
#
# Epoch 15
#
# Training: 30 batches [00:04,  6.89 batches/s]
# Evaluation: 8 batches [00:01,  6.40 batches/s]
# The achieved test AUC: 0.7872110896087399
# Best model saved to best_dkt_model_embed_dim_3.pth
# Best configuration saved to best_dkt_config_embed_dim_3.json

# %% [markdown]
# The achieved AUC with an embedding dimension of 2 is 0.7872, which is far below the 0.87 achieved in the paper.
